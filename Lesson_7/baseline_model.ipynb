# %%
import time
import numpy as np
import pandas as pd
import catboost as cb

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

pd.set_option("display.max_columns", 30)

# %% [markdown]
# ## Useful Functions

# %%
def get_input(data_path: str) -> pd.DataFrame:
    """
    Считывание данных и вывод основной информации о наборе данных.

    Parameters
    ----------
    data_path: str
        Название файла.

    Returns
    -------
    data: pandas.core.frame.DataFrame
        Загруженный набор данных в pandas.DataFrame

    """
    base_path = "../geekbrains-competitive-data-analysis"
    data = pd.read_csv(f"{base_path}/{data_path}")
    data.columns = [col.lower() for col in data.columns]
    print(f"{data_path}: shape = {data.shape[0]} rows, {data.shape[1]} cols")

    return data


def catboost_cross_validation(params, X, y, cv, categorical = None):
    """
    Кросс-валидация для модели catbooost.

    Parameters
    ----------
    params: dict
        Словарь гиперпараметров модели.

    X: pandas.core.frame.DataFrame
        Матрица признако для обучения модели.

    y: pandas.core.frame.Series
        Вектор целевой переменной для обучения модели.

    cv: KFold or StratifiedKFold generator.
        Объект KFold / StratifiedKFold для определения
        стратегии кросс-валидации модели.

    categorical: str, optional, default = None
        Список категориальных признаков.
        Опциональный параметр, по умолчанию, не используется.

    Returns
    -------
    estimators: list
        Список с объектами обученной модели.

    oof_preds: np.array
        Вектор OOF-прогнозов.

    """
    estimators, folds_scores = [], []
    oof_preds = np.zeros(X.shape[0])

    print(f"{time.ctime()}, Cross-Validation, {X.shape[0]} rows, {X.shape[1]} cols")
    X[categorical] = X[categorical].astype(str)

    for fold, (train_idx, valid_idx) in enumerate(cv.split(X, y)):

        x_train, x_valid = X.loc[train_idx], X.loc[valid_idx]
        y_train, y_valid = y[train_idx], y[valid_idx]

        model = cb.CatBoostClassifier(**params)
        model.fit(
            x_train, y_train, categorical,
            eval_set=[(x_train, y_train), (x_valid, y_valid)]
        )
        oof_preds[valid_idx] = model.predict_proba(x_valid)[:, 1]
        score = roc_auc_score(y_valid, oof_preds[valid_idx])
        print(f"Fold {fold+1}, Valid score = {round(score, 5)}")
        folds_scores.append(round(score, 5))
        estimators.append(model)

    print(f"Score by each fold: {folds_scores}")
    print("="*65)
    return estimators, oof_preds


def catboost_hold_out_validation(params, X, y, split_params = [0.7, 0.2, 0.1], categorical = None):
    """
    Hold-Out валидация для модели catbooost.

    Parameters
    ----------
    params: dict
        Словарь гиперпараметров модели.

    X: pandas.core.frame.DataFrame
        Матрица признако для обучения модели.

    y: pandas.core.frame.Series
        Вектор целевой переменной для обучения модели.

    split_params: List[float], optional, default = [0.7, 0.2, 0.1]
        Параметры (доли) разбиения выборки.
        Опциональный параметр, по умолчанию, равен [0.7, 0.2, 0.1].
    
    categorical: str, optional, default = None
        Список категориальных признаков.
        Опциональный параметр, по умолчанию, не используется.

    Returns
    -------
    estimator: catboost.core.CatBoostClassifier
        Обученный классификатор catboost.

    test_prediction: np.array, optional
        Вектор прогнозов для тестовой выборки.
        Опциональный объект, возвращается только, если split_params
        содержит 3 значения.

    """
    numeric = list(set(x_train.columns) - set(categorical))
    x_train, x_valid = train_test_split(
        X, train_size=split_params[0], random_state=27
    )
    y_train, y_valid = train_test_split(
        y, train_size=split_params[0], random_state=27
    )

    if len(split_params) == 3:
        test_size = int(split_params[2] * X.shape[0])

        x_valid, x_test = train_test_split(
            x_valid, test_size=test_size, random_state=72
        )
        y_valid, y_test = train_test_split(
            y_valid, test_size=test_size, random_state=72
        )

    model = cb.CatBoostClassifier(**params)
    model.fit(
        x_train, y_train, categorical,
        eval_set=[(x_train, y_train), (x_valid, y_valid)]
    )

    print("="*80)
    valid_score = roc_auc_score(y_valid, model.predict_proba(x_valid)[:, 1])
    print(f"Valid Score = {round(valid_score, 4)}")

    if len(split_params) == 3:

        test_prediction = model.predict_proba(x_test)[:, 1]
        test_score = roc_auc_score(y_test, test_prediction)
        print(f"Test Score = {round(test_score, 4)}")

        return estimator, test_prediction

    else:
        return estimator

# %%
def create_client_profile_features(X: pd.DataFrame, copy: bool = True) -> pd.DataFrame:
    """
    Создание признаков на основе профиля клиентов.

    Parameters
    ----------
    X: pandas.core.frame.DataFrame
        Матрица признаков с исходным профилем клиента.

    copy: bool, optional, default = True
        Флаг использования копии датафрейма X.
        Опциональный параметр, по умолчанию, равен True.

    Returns
    -------
    X_transformed: pandas.core.frame.DataFrame
        Расширенная матрица признаков с профилем клиентов.

    """
    if copy:
        X = X.copy()

    X["days_on_last_job"] = X["days_on_last_job"].replace(365243, np.nan)
    bki_flags = [flag for flag in X.columns if "amt_req_credit_bureau" in flag]
    X["bki_requests_count"] = X[bki_flags].sum(axis=1)
    X["bki_kurtosis"] = X[bki_flags].kurtosis(axis=1)

    X["external_scoring_prod"] = X["external_scoring_rating_1"] * X["external_scoring_rating_2"] * X["external_scoring_rating_3"]
    X["external_scoring_weighted"] = X.external_scoring_rating_1 * 2 + X.external_scoring_rating_2 * 1 + X.external_scoring_rating_3 * 3

    for function_name in ["min", "max", "mean", "nanmedian", "var"]:
        feature_name = "external_scoring_rating_{}".format(function_name)
        X[feature_name] = eval("np.{}".format(function_name))(
            X[["external_scoring_rating_1", "external_scoring_rating_2", "external_scoring_rating_3"]], axis=1
        )

    # Отношение между основными фин. показателями
    X['ratio_credit_to_annuity'] = X['amount_credit'] / X['amount_annuity']
    X["ratio_annuity_to_salary"] = X['amount_annuity'] / X['total_salary']
    X['ratio_credit_to_salary'] = X['amount_credit'] / X['total_salary']
    #X["total_salary_net"] = X["total_salary"] - X["amount_annuity"]

    # Отношение фин. показателей к возрасту и временным фичам
    X["ratio_annuity_to_age"] = X["amount_annuity"] / X["age"]
    X["ratio_credit_to_age"] = X["amount_credit"] / X["age"]
    X["ratio_salary_to_age"] = X["total_salary"] / X["age"]
    X["ratio_salary_to_experience"] = X["total_salary"] / X["days_on_last_job"]
    X["ratio_credit_to_experience"] = X["amount_credit"] / X["days_on_last_job"]
    X["ratio_annuity_to_experience"] = X["amount_annuity"] / X["days_on_last_job"]

    # Отношение врменных признаков
    X["ratio_age_to_experience"] = X["age"] / X["days_on_last_job"]
    X["ratio_salary_to_region_population"] = X["total_salary"] * X["region_population"]
    X["ratio_car_to_experience"] = X["own_car_age"] / X["days_on_last_job"]
    X["ratio_car_to_age"] = X["own_car_age"] / X["age"]

    # Произведение фин. показателей кредита на вероятность дефолта
    # Такая штука называется математическим ожиданием дефолта или ожидаемыми потерями
    X["expected_total_loss_1"] = X["external_scoring_rating_1"] * X["amount_credit"]
    X["expected_total_loss_2"] = X["external_scoring_rating_2"] * X["amount_credit"]
    X["expected_total_loss_3"] = X["external_scoring_rating_3"] * X["amount_credit"]
    X["expected_monthly_loss_1"] = X["external_scoring_rating_1"] * X["amount_annuity"]
    X["expected_monthly_loss_2"] = X["external_scoring_rating_2"] * X["amount_annuity"]
    X["expected_monthly_loss_3"] = X["external_scoring_rating_3"] * X["amount_annuity"]

    return X

# %% [markdown]
# ## Base Tables

# %%
train = get_input("train.csv")
test = get_input("test.csv")

data = pd.concat([train, test], axis=0)
data = data.reset_index(drop=True)
data.head(n=2)
# Out:
# train.csv: shape = 110093 rows, 3 cols
# test.csv: shape = 165141 rows, 2 cols
#    application_number  target name_contract_type
# 0           123687442     0.0               Cash
# 1           123597908     1.0               Cash

# %% [markdown]
# ## client_profile

# %%
client_profile = get_input("client_profile.csv")
client_profile = create_client_profile_features(client_profile)
client_profile.head(n=2)
# Out:
# client_profile.csv: shape = 250000 rows, 24 cols
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1115: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
#    application_number gender  childrens  total_salary  amount_credit  \
# 0           123666076      F          0      157500.0       270000.0
# 1           123423688      F          0      270000.0       536917.5
#
#    amount_annuity                education_level   family_status  \
# 0         13500.0              Incomplete higher  Civil marriage
# 1         28467.0  Secondary / secondary special         Married
#
#    region_population    age  days_on_last_job  own_car_age  flag_phone  \
# 0           0.008068   8560            1549.0          NaN           1
# 1           0.020246  23187               NaN          NaN           0
#
#    flag_email  family_size  ...  ratio_credit_to_age  ratio_salary_to_age  \
# 0           0          2.0  ...            31.542056            18.399533
# 1           0          2.0  ...            23.155971            11.644456
#
#    ratio_salary_to_experience  ratio_credit_to_experience  \
# 0                  101.678502                  174.306004
# 1                         NaN                         NaN
#
#    ratio_annuity_to_experience  ratio_age_to_experience  \
# 0                       8.7153                 5.526146
# 1                          NaN                      NaN
#
#    ratio_salary_to_region_population  ratio_car_to_experience  \
# 0                            1270.71                      NaN
# 1                            5466.42                      NaN
#
#    ratio_car_to_age  expected_total_loss_1  expected_total_loss_2  \
# 0               NaN           88957.124333           63804.966560
# 1               NaN                    NaN          237475.743779
#
#    expected_total_loss_3  expected_monthly_loss_1  expected_monthly_loss_2  \
# 0          183213.275945              4447.856217              3190.248328
# 1          431008.094056                      NaN             12590.802122
#
#    expected_monthly_loss_3
# 0              9160.663797
# 1             22851.755462
#
# [2 rows x 52 columns]

# %%
data = data.merge(
    client_profile, how="left", on="application_number"
)

# %%
data.head(20)
# Out:
#     application_number  target name_contract_type gender  childrens  \
# 0            123687442     0.0               Cash      M        1.0
# 1            123597908     1.0               Cash    NaN        NaN
# 2            123526683     0.0               Cash      F        0.0
# 3            123710391     1.0               Cash      M        0.0
# 4            123590329     1.0               Cash    NaN        NaN
# 5            123718821     0.0               Cash      F        1.0
# 6            123544624     0.0               Cash      M        0.0
# 7            123631154     0.0               Cash      M        0.0
# 8            123702544     0.0               Cash      M        0.0
# 9            123660201     0.0               Cash      M        0.0
# 10           123572161     0.0               Cash    NaN        NaN
# 11           123676382     0.0               Cash      M        0.0
# 12           123728314     0.0               Cash      F        0.0
# 13           123525176     0.0               Cash      F        2.0
# 14           123600510     0.0               Cash      F        0.0
# 15           123572982     0.0               Cash      M        0.0
# 16           123649339     0.0               Cash    NaN        NaN
# 17           123646531     1.0               Cash    NaN        NaN
# 18           123724887     0.0               Cash      F        0.0
# 19           123539862     0.0               Cash      F        0.0
#
#     total_salary  amount_credit  amount_annuity  \
# 0       157500.0       855000.0         25128.0
# 1            NaN            NaN             NaN
# 2       135000.0      1006920.0         42660.0
# 3       180000.0       518562.0         22972.5
# 4            NaN            NaN             NaN
# 5       180000.0       755190.0         36459.0
# 6       202500.0      1078200.0         38331.0
# 7        99000.0        90000.0         10179.0
# 8       135000.0       171000.0          8446.5
# 9       225000.0       473760.0         51151.5
# 10           NaN            NaN             NaN
# 11      441000.0      1574532.0         60102.0
# 12      117000.0       540000.0         17419.5
# 13      157500.0       508495.5         24462.0
# 14       90000.0       485640.0         31401.0
# 15      121500.0       123993.0          5589.0
# 16           NaN            NaN             NaN
# 17           NaN            NaN             NaN
# 18      202500.0       545040.0         19705.5
# 19      315000.0       467257.5         17613.0
#
#                   education_level         family_status  region_population  \
# 0   Secondary / secondary special               Married           0.019101
# 1                             NaN                   NaN                NaN
# 2                Higher education               Married           0.026392
# 3   Secondary / secondary special               Married           0.031329
# 4                             NaN                   NaN                NaN
# 5   Secondary / secondary special               Married           0.010032
# 6   Secondary / secondary special               Married           0.031329
# 7   Secondary / secondary special  Single / not married           0.011703
# 8                Higher education  Single / not married           0.006296
# 9   Secondary / secondary special  Single / not married           0.018801
# 10                            NaN                   NaN                NaN
# 11  Secondary / secondary special               Married           0.046220
# 12               Higher education             Separated           0.010643
# 13               Higher education               Married           0.010276
# 14  Secondary / secondary special               Married           0.024610
# 15                Lower secondary               Married           0.007305
# 16                            NaN                   NaN                NaN
# 17                            NaN                   NaN                NaN
# 18               Higher education               Married           0.009630
# 19  Secondary / secondary special               Married           0.035792
#
#         age  days_on_last_job  own_car_age  flag_phone  ...  \
# 0   15728.0            1719.0         11.0         0.0  ...
# 1       NaN               NaN          NaN         NaN  ...
# 2   21557.0            3618.0          NaN         1.0  ...
# 3   22338.0               NaN          NaN         0.0  ...
# 4       NaN               NaN          NaN         NaN  ...
# 5   16049.0             187.0         20.0         1.0  ...
# 6   23087.0           16364.0          NaN         1.0  ...
# 7    9334.0             253.0          NaN         0.0  ...
# 8   12205.0             351.0         14.0         0.0  ...
# 9    9494.0             163.0         18.0         1.0  ...
# 10      NaN               NaN          NaN         NaN  ...
# 11  14536.0             170.0         12.0         0.0  ...
# 12  17444.0            9026.0          8.0         0.0  ...
# 13  15801.0             576.0          3.0         0.0  ...
# 14  17170.0             356.0          NaN         0.0  ...
# 15  22454.0               NaN         12.0         1.0  ...
# 16      NaN               NaN          NaN         NaN  ...
# 17      NaN               NaN          NaN         NaN  ...
# 18  20720.0               NaN          NaN         0.0  ...
# 19  18562.0            3379.0          6.0         0.0  ...
#
#     ratio_credit_to_age  ratio_salary_to_age  ratio_salary_to_experience  \
# 0             54.361648            10.013988                   91.623037
# 1                   NaN                  NaN                         NaN
# 2             46.709653             6.262467                   37.313433
# 3             23.214343             8.058018                         NaN
# 4                   NaN                  NaN                         NaN
# 5             47.055268            11.215652                  962.566845
# 6             46.701607             8.771170                   12.374725
# 7              9.642168            10.606385                  391.304348
# 8             14.010651            11.061041                  384.615385
# 9             49.900990            23.699178                 1380.368098
# 10                  NaN                  NaN                         NaN
# 11           108.319483            30.338470                 2594.117647
# 12            30.956203             6.707177                   12.962553
# 13            32.181223             9.967724                  273.437500
# 14            28.284217             5.241701                  252.808989
# 15             5.522090             5.411063                         NaN
# 16                  NaN                  NaN                         NaN
# 17                  NaN                  NaN                         NaN
# 18            26.305019             9.773166                         NaN
# 19            25.172799            16.970154                   93.222847
#
#     ratio_credit_to_experience  ratio_annuity_to_experience  \
# 0                   497.382199                    14.617801
# 1                          NaN                          NaN
# 2                   278.308458                    11.791045
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 5                  4038.449198                   194.967914
# 6                    65.888536                     2.342398
# 7                   355.731225                    40.233202
# 8                   487.179487                    24.064103
# 9                  2906.503067                   313.812883
# 10                         NaN                          NaN
# 11                 9261.952941                   353.541176
# 12                   59.827166                     1.929925
# 13                  882.804688                    42.468750
# 14                 1364.157303                    88.205056
# 15                         NaN                          NaN
# 16                         NaN                          NaN
# 17                         NaN                          NaN
# 18                         NaN                          NaN
# 19                  138.282776                     5.212489
#
#     ratio_age_to_experience  ratio_salary_to_region_population  \
# 0                  9.149506                          3008.4075
# 1                       NaN                                NaN
# 2                  5.958264                          3562.9200
# 3                       NaN                          5639.2200
# 4                       NaN                                NaN
# 5                 85.823529                          1805.7600
# 6                  1.410841                          6344.1225
# 7                 36.893281                          1158.5970
# 8                 34.772080                           849.9600
# 9                 58.245399                          4230.2250
# 10                      NaN                                NaN
# 11                85.505882                         20383.0200
# 12                 1.932639                          1245.2310
# 13                27.432292                          1618.4700
# 14                48.230337                          2214.9000
# 15                      NaN                           887.5575
# 16                      NaN                                NaN
# 17                      NaN                                NaN
# 18                      NaN                          1950.0750
# 19                 5.493341                         11274.4800
#
#     ratio_car_to_experience  ratio_car_to_age  expected_total_loss_1  \
# 0                  0.006399          0.000699          599170.547652
# 1                       NaN               NaN                    NaN
# 2                       NaN               NaN                    NaN
# 3                       NaN               NaN                    NaN
# 4                       NaN               NaN                    NaN
# 5                  0.106952          0.001246                    NaN
# 6                       NaN               NaN                    NaN
# 7                       NaN               NaN           26394.291170
# 8                  0.039886          0.001147           33396.658223
# 9                  0.110429          0.001896                    NaN
# 10                      NaN               NaN                    NaN
# 11                 0.070588          0.000826                    NaN
# 12                 0.000886          0.000459          362402.546771
# 13                 0.005208          0.000190          308467.142453
# 14                      NaN               NaN           32549.964349
# 15                      NaN          0.000534                    NaN
# 16                      NaN               NaN                    NaN
# 17                      NaN               NaN                    NaN
# 18                      NaN               NaN          487641.484089
# 19                 0.001776          0.000323          377231.073852
#
#     expected_total_loss_2  expected_total_loss_3  expected_monthly_loss_1  \
# 0           552256.266546          612667.559305             17609.307043
# 1                     NaN                    NaN                      NaN
# 2           686869.876357          269722.588880                      NaN
# 3            88829.188848           88386.882459                      NaN
# 4                     NaN                    NaN                      NaN
# 5           414224.915008          250157.340430                      NaN
# 6           590229.235465          798729.576650                      NaN
# 7            58819.293046           11565.393964              2985.194331
# 8            54629.860798          101228.001732              1649.619144
# 9           260539.064613          244221.088936                      NaN
# 10                    NaN                    NaN                      NaN
# 11          652209.909698          791797.939569                      NaN
# 12          358416.487120          235713.509513             11690.502155
# 13          310819.015218           54679.627501             14839.311732
# 14          303020.435333                    NaN              2104.648362
# 15           41364.641268           44713.433886                      NaN
# 16                    NaN                    NaN                      NaN
# 17                    NaN                    NaN                      NaN
# 18          256722.632456          229249.799842             17630.301014
# 19           87582.196205          311125.706200             14219.506169
#
#     expected_monthly_loss_2  expected_monthly_loss_3
# 0              16230.521013             18005.977111
# 1                       NaN                      NaN
# 2              29100.493510             11427.288803
# 3               3935.167908              3915.573562
# 4                       NaN                      NaN
# 5              19997.915990             12077.075272
# 6              20983.191267             28395.569841
# 7               6652.462044              1308.046057
# 8               2698.427598              5000.130507
# 9              28130.200869             26368.361683
# 10                      NaN                      NaN
# 11             24895.727742             30223.990217
# 12             11561.918514              7603.724961
# 13             14952.452382              2630.452084
# 14             19593.000350                      NaN
# 15              1864.516384              2015.463631
# 16                      NaN                      NaN
# 17                      NaN                      NaN
# 18              9281.608384              8288.349352
# 19              3301.360003             11727.702741
#
# [20 rows x 54 columns]

# %% [markdown]
# ## baseline

# %%
mask = data["target"].isnull()
features_to_drop = ["application_number", "target"]

train, test = data.loc[~mask], data.loc[mask]

target, test_id = train["target"], test["application_number"]
train = train.drop(features_to_drop, axis=1)
test = test.drop(features_to_drop, axis=1)

categorial = train.dtypes[train.dtypes == "object"].index
numerical = list(set(train.columns) - set(categorial))

train = train.replace(np.inf, np.nan)
train = train.replace(-np.inf, np.nan)

# %%
train.head(30)
# Out:
#    name_contract_type gender  childrens  total_salary  amount_credit  \
# 0                Cash      M        1.0      157500.0       855000.0
# 1                Cash    NaN        NaN           NaN            NaN
# 2                Cash      F        0.0      135000.0      1006920.0
# 3                Cash      M        0.0      180000.0       518562.0
# 4                Cash    NaN        NaN           NaN            NaN
# 5                Cash      F        1.0      180000.0       755190.0
# 6                Cash      M        0.0      202500.0      1078200.0
# 7                Cash      M        0.0       99000.0        90000.0
# 8                Cash      M        0.0      135000.0       171000.0
# 9                Cash      M        0.0      225000.0       473760.0
# 10               Cash    NaN        NaN           NaN            NaN
# 11               Cash      M        0.0      441000.0      1574532.0
# 12               Cash      F        0.0      117000.0       540000.0
# 13               Cash      F        2.0      157500.0       508495.5
# 14               Cash      F        0.0       90000.0       485640.0
# 15               Cash      M        0.0      121500.0       123993.0
# 16               Cash    NaN        NaN           NaN            NaN
# 17               Cash    NaN        NaN           NaN            NaN
# 18               Cash      F        0.0      202500.0       545040.0
# 19               Cash      F        0.0      315000.0       467257.5
# 20               Cash      F        0.0       90000.0       284400.0
# 21               Cash      M        2.0      315000.0      1165500.0
# 22               Cash      F        2.0      135000.0       361462.5
# 23               Cash      F        0.0      112500.0       794173.5
# 24               Cash      F        0.0      247500.0       646920.0
# 25               Cash    NaN        NaN           NaN            NaN
# 26               Cash      F        0.0      157500.0       355536.0
# 27        Credit Card      F        2.0      202500.0       360000.0
# 28               Cash    NaN        NaN           NaN            NaN
# 29               Cash    NaN        NaN           NaN            NaN
#
#     amount_annuity                education_level         family_status  \
# 0          25128.0  Secondary / secondary special               Married
# 1              NaN                            NaN                   NaN
# 2          42660.0               Higher education               Married
# 3          22972.5  Secondary / secondary special               Married
# 4              NaN                            NaN                   NaN
# 5          36459.0  Secondary / secondary special               Married
# 6          38331.0  Secondary / secondary special               Married
# 7          10179.0  Secondary / secondary special  Single / not married
# 8           8446.5               Higher education  Single / not married
# 9          51151.5  Secondary / secondary special  Single / not married
# 10             NaN                            NaN                   NaN
# 11         60102.0  Secondary / secondary special               Married
# 12         17419.5               Higher education             Separated
# 13         24462.0               Higher education               Married
# 14         31401.0  Secondary / secondary special               Married
# 15          5589.0                Lower secondary               Married
# 16             NaN                            NaN                   NaN
# 17             NaN                            NaN                   NaN
# 18         19705.5               Higher education               Married
# 19         17613.0  Secondary / secondary special               Married
# 20         16456.5  Secondary / secondary special               Married
# 21         34209.0  Secondary / secondary special               Married
# 22         24579.0  Secondary / secondary special               Married
# 23         40680.0  Secondary / secondary special               Married
# 24         20997.0  Secondary / secondary special               Married
# 25             NaN                            NaN                   NaN
# 26         18283.5  Secondary / secondary special               Married
# 27         18000.0  Secondary / secondary special        Civil marriage
# 28             NaN                            NaN                   NaN
# 29             NaN                            NaN                   NaN
#
#     region_population      age  days_on_last_job  own_car_age  flag_phone  \
# 0            0.019101  15728.0            1719.0         11.0         0.0
# 1                 NaN      NaN               NaN          NaN         NaN
# 2            0.026392  21557.0            3618.0          NaN         1.0
# 3            0.031329  22338.0               NaN          NaN         0.0
# 4                 NaN      NaN               NaN          NaN         NaN
# 5            0.010032  16049.0             187.0         20.0         1.0
# 6            0.031329  23087.0           16364.0          NaN         1.0
# 7            0.011703   9334.0             253.0          NaN         0.0
# 8            0.006296  12205.0             351.0         14.0         0.0
# 9            0.018801   9494.0             163.0         18.0         1.0
# 10                NaN      NaN               NaN          NaN         NaN
# 11           0.046220  14536.0             170.0         12.0         0.0
# 12           0.010643  17444.0            9026.0          8.0         0.0
# 13           0.010276  15801.0             576.0          3.0         0.0
# 14           0.024610  17170.0             356.0          NaN         0.0
# 15           0.007305  22454.0               NaN         12.0         1.0
# 16                NaN      NaN               NaN          NaN         NaN
# 17                NaN      NaN               NaN          NaN         NaN
# 18           0.009630  20720.0               NaN          NaN         0.0
# 19           0.035792  18562.0            3379.0          6.0         0.0
# 20           0.010966  23855.0               NaN          NaN         0.0
# 21           0.018209  12102.0            1904.0          NaN         0.0
# 22           0.035792  15960.0            2295.0          NaN         0.0
# 23           0.031329  20825.0               NaN         10.0         0.0
# 24           0.006207  23241.0               NaN          NaN         0.0
# 25                NaN      NaN               NaN          NaN         NaN
# 26           0.008068  18155.0            5984.0          NaN         0.0
# 27           0.035792  12778.0            3582.0          NaN         0.0
# 28                NaN      NaN               NaN          NaN         NaN
# 29                NaN      NaN               NaN          NaN         NaN
#
#     flag_email  family_size  ...  ratio_credit_to_age  ratio_salary_to_age  \
# 0          0.0          3.0  ...            54.361648            10.013988
# 1          NaN          NaN  ...                  NaN                  NaN
# 2          0.0          2.0  ...            46.709653             6.262467
# 3          0.0          2.0  ...            23.214343             8.058018
# 4          NaN          NaN  ...                  NaN                  NaN
# 5          0.0          3.0  ...            47.055268            11.215652
# 6          0.0          2.0  ...            46.701607             8.771170
# 7          0.0          1.0  ...             9.642168            10.606385
# 8          0.0          1.0  ...            14.010651            11.061041
# 9          0.0          1.0  ...            49.900990            23.699178
# 10         NaN          NaN  ...                  NaN                  NaN
# 11         0.0          2.0  ...           108.319483            30.338470
# 12         0.0          1.0  ...            30.956203             6.707177
# 13         0.0          4.0  ...            32.181223             9.967724
# 14         0.0          2.0  ...            28.284217             5.241701
# 15         0.0          2.0  ...             5.522090             5.411063
# 16         NaN          NaN  ...                  NaN                  NaN
# 17         NaN          NaN  ...                  NaN                  NaN
# 18         0.0          2.0  ...            26.305019             9.773166
# 19         0.0          2.0  ...            25.172799            16.970154
# 20         0.0          2.0  ...            11.922029             3.772794
# 21         0.0          4.0  ...            96.306396            26.028756
# 22         0.0          4.0  ...            22.648026             8.458647
# 23         0.0          2.0  ...            38.135582             5.402161
# 24         0.0          2.0  ...            27.835291            10.649284
# 25         NaN          NaN  ...                  NaN                  NaN
# 26         0.0          2.0  ...            19.583365             8.675296
# 27         0.0          4.0  ...            28.173423            15.847550
# 28         NaN          NaN  ...                  NaN                  NaN
# 29         NaN          NaN  ...                  NaN                  NaN
#
#     ratio_salary_to_experience  ratio_credit_to_experience  \
# 0                    91.623037                  497.382199
# 1                          NaN                         NaN
# 2                    37.313433                  278.308458
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# 5                   962.566845                 4038.449198
# 6                    12.374725                   65.888536
# 7                   391.304348                  355.731225
# 8                   384.615385                  487.179487
# 9                  1380.368098                 2906.503067
# 10                         NaN                         NaN
# 11                 2594.117647                 9261.952941
# 12                   12.962553                   59.827166
# 13                  273.437500                  882.804688
# 14                  252.808989                 1364.157303
# 15                         NaN                         NaN
# 16                         NaN                         NaN
# 17                         NaN                         NaN
# 18                         NaN                         NaN
# 19                   93.222847                  138.282776
# 20                         NaN                         NaN
# 21                  165.441176                  612.132353
# 22                   58.823529                  157.500000
# 23                         NaN                         NaN
# 24                         NaN                         NaN
# 25                         NaN                         NaN
# 26                   26.320187                   59.414439
# 27                   56.532663                  100.502513
# 28                         NaN                         NaN
# 29                         NaN                         NaN
#
#     ratio_annuity_to_experience  ratio_age_to_experience  \
# 0                     14.617801                 9.149506
# 1                           NaN                      NaN
# 2                     11.791045                 5.958264
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# 5                    194.967914                85.823529
# 6                      2.342398                 1.410841
# 7                     40.233202                36.893281
# 8                     24.064103                34.772080
# 9                    313.812883                58.245399
# 10                          NaN                      NaN
# 11                   353.541176                85.505882
# 12                     1.929925                 1.932639
# 13                    42.468750                27.432292
# 14                    88.205056                48.230337
# 15                          NaN                      NaN
# 16                          NaN                      NaN
# 17                          NaN                      NaN
# 18                          NaN                      NaN
# 19                     5.212489                 5.493341
# 20                          NaN                      NaN
# 21                    17.966912                 6.356092
# 22                    10.709804                 6.954248
# 23                          NaN                      NaN
# 24                          NaN                      NaN
# 25                          NaN                      NaN
# 26                     3.055398                 3.033924
# 27                     5.025126                 3.567281
# 28                          NaN                      NaN
# 29                          NaN                      NaN
#
#     ratio_salary_to_region_population  ratio_car_to_experience  \
# 0                           3008.4075                 0.006399
# 1                                 NaN                      NaN
# 2                           3562.9200                      NaN
# 3                           5639.2200                      NaN
# 4                                 NaN                      NaN
# 5                           1805.7600                 0.106952
# 6                           6344.1225                      NaN
# 7                           1158.5970                      NaN
# 8                            849.9600                 0.039886
# 9                           4230.2250                 0.110429
# 10                                NaN                      NaN
# 11                         20383.0200                 0.070588
# 12                          1245.2310                 0.000886
# 13                          1618.4700                 0.005208
# 14                          2214.9000                      NaN
# 15                           887.5575                      NaN
# 16                                NaN                      NaN
# 17                                NaN                      NaN
# 18                          1950.0750                      NaN
# 19                         11274.4800                 0.001776
# 20                           986.9400                      NaN
# 21                          5735.8350                      NaN
# 22                          4831.9200                      NaN
# 23                          3524.5125                      NaN
# 24                          1536.2325                      NaN
# 25                                NaN                      NaN
# 26                          1270.7100                      NaN
# 27                          7247.8800                      NaN
# 28                                NaN                      NaN
# 29                                NaN                      NaN
#
#     ratio_car_to_age  expected_total_loss_1  expected_total_loss_2  \
# 0           0.000699          599170.547652          552256.266546
# 1                NaN                    NaN                    NaN
# 2                NaN                    NaN          686869.876357
# 3                NaN                    NaN           88829.188848
# 4                NaN                    NaN                    NaN
# 5           0.001246                    NaN          414224.915008
# 6                NaN                    NaN          590229.235465
# 7                NaN           26394.291170           58819.293046
# 8           0.001147           33396.658223           54629.860798
# 9           0.001896                    NaN          260539.064613
# 10               NaN                    NaN                    NaN
# 11          0.000826                    NaN          652209.909698
# 12          0.000459          362402.546771          358416.487120
# 13          0.000190          308467.142453          310819.015218
# 14               NaN           32549.964349          303020.435333
# 15          0.000534                    NaN           41364.641268
# 16               NaN                    NaN                    NaN
# 17               NaN                    NaN                    NaN
# 18               NaN          487641.484089          256722.632456
# 19          0.000323          377231.073852           87582.196205
# 20               NaN                    NaN          148811.376301
# 21               NaN                    NaN          393139.922580
# 22               NaN          166228.770797          108438.915494
# 23          0.000480                    NaN          502565.127602
# 24               NaN                    NaN          156648.432750
# 25               NaN                    NaN                    NaN
# 26               NaN          241290.903895          155183.377286
# 27               NaN                    NaN          244835.142443
# 28               NaN                    NaN                    NaN
# 29               NaN                    NaN                    NaN
#
#     expected_total_loss_3  expected_monthly_loss_1  expected_monthly_loss_2  \
# 0           612667.559305             17609.307043             16230.521013
# 1                     NaN                      NaN                      NaN
# 2           269722.588880                      NaN             29100.493510
# 3            88386.882459                      NaN              3935.167908
# 4                     NaN                      NaN                      NaN
# 5           250157.340430                      NaN             19997.915990
# 6           798729.576650                      NaN             20983.191267
# 7            11565.393964              2985.194331              6652.462044
# 8           101228.001732              1649.619144              2698.427598
# 9           244221.088936                      NaN             28130.200869
# 10                    NaN                      NaN                      NaN
# 11          791797.939569                      NaN             24895.727742
# 12          235713.509513             11690.502155             11561.918514
# 13           54679.627501             14839.311732             14952.452382
# 14                    NaN              2104.648362             19593.000350
# 15           44713.433886                      NaN              1864.516384
# 16                    NaN                      NaN                      NaN
# 17                    NaN                      NaN                      NaN
# 18          229249.799842             17630.301014              9281.608384
# 19          311125.706200             14219.506169              3301.360003
# 20           43210.185750                      NaN              8610.810176
# 21             614.527636                      NaN             11539.187998
# 22                    NaN             11303.349469              7373.711253
# 23          254265.261634                      NaN             25742.925684
# 24          443028.708959                      NaN              5084.318219
# 25                    NaN                      NaN                      NaN
# 26           96753.321622             12408.426267              7980.331889
# 27          229695.670034                      NaN             12241.757122
# 28                    NaN                      NaN                      NaN
# 29                    NaN                      NaN                      NaN
#
#     expected_monthly_loss_3
# 0              18005.977111
# 1                       NaN
# 2              11427.288803
# 3               3915.573562
# 4                       NaN
# 5              12077.075272
# 6              28395.569841
# 7               1308.046057
# 8               5000.130507
# 9              26368.361683
# 10                      NaN
# 11             30223.990217
# 12              7603.724961
# 13              2630.452084
# 14                      NaN
# 15              2015.463631
# 16                      NaN
# 17                      NaN
# 18              8288.349352
# 19             11727.702741
# 20              2500.310906
# 21                18.037217
# 22                      NaN
# 23             13024.245764
# 24             14379.326349
# 25                      NaN
# 26              4975.556219
# 27             11484.783502
# 28                      NaN
# 29                      NaN
#
# [30 rows x 52 columns]

# %% [markdown]
# ## KFold

# %%
cb_params = {
    "n_estimators": 2000,
    "learning_rate": 0.01,
    "loss_function": "Logloss",
    "eval_metric": "AUC",
    "task_type": "CPU",
    "max_bin": 20,
    "verbose": 10,
    "max_depth": 6,
    "l2_leaf_reg": 10,
    "early_stopping_rounds": 50,
    "thread_count": 6,
    "random_seed": 42
}

cv = KFold(n_splits=5, random_state=1234123, shuffle=True)

estimators, oof_preds = catboost_cross_validation(
    params=cb_params, X=train, y=target, cv=cv, categorical=categorial
)
# Out:
# Thu Dec 10 14:25:36 2020, Cross-Validation, 110093 rows, 52 cols
# 0:	test: 0.5867378	test1: 0.5812295	best: 0.5812295 (0)	total: 209ms	remaining: 6m 57s
# 10:	test: 0.7001402	test1: 0.6925714	best: 0.6925714 (10)	total: 1.33s	remaining: 4m
# 20:	test: 0.7035652	test1: 0.6963165	best: 0.6963165 (20)	total: 2.33s	remaining: 3m 39s
# 30:	test: 0.7047232	test1: 0.6979904	best: 0.6979904 (30)	total: 3.36s	remaining: 3m 33s
# 40:	test: 0.7054465	test1: 0.6992489	best: 0.6994170 (38)	total: 4.38s	remaining: 3m 29s
# 50:	test: 0.7069468	test1: 0.7006301	best: 0.7006301 (50)	total: 5.38s	remaining: 3m 25s
# 60:	test: 0.7081454	test1: 0.7013650	best: 0.7013650 (60)	total: 6.36s	remaining: 3m 22s
# 70:	test: 0.7090323	test1: 0.7018906	best: 0.7018906 (70)	total: 7.36s	remaining: 3m 20s
# 80:	test: 0.7095323	test1: 0.7027972	best: 0.7027972 (80)	total: 8.36s	remaining: 3m 18s
# 90:	test: 0.7093081	test1: 0.7030943	best: 0.7032636 (89)	total: 9.37s	remaining: 3m 16s
# 100:	test: 0.7099472	test1: 0.7032162	best: 0.7033444 (96)	total: 10.4s	remaining: 3m 15s
# 110:	test: 0.7102535	test1: 0.7029461	best: 0.7036181 (102)	total: 11.4s	remaining: 3m 13s
# 120:	test: 0.7108259	test1: 0.7034438	best: 0.7037579 (112)	total: 12.4s	remaining: 3m 12s
# 130:	test: 0.7112779	test1: 0.7038516	best: 0.7038516 (130)	total: 13.4s	remaining: 3m 11s
# 140:	test: 0.7117093	test1: 0.7044894	best: 0.7044894 (140)	total: 14.4s	remaining: 3m 9s
# 150:	test: 0.7123586	test1: 0.7048541	best: 0.7048541 (150)	total: 15.4s	remaining: 3m 8s
# 160:	test: 0.7132655	test1: 0.7057592	best: 0.7057592 (160)	total: 16.4s	remaining: 3m 7s
# 170:	test: 0.7144556	test1: 0.7069537	best: 0.7071913 (169)	total: 17.3s	remaining: 3m 5s
# 180:	test: 0.7152808	test1: 0.7074203	best: 0.7074203 (180)	total: 18.3s	remaining: 3m 3s
# 190:	test: 0.7159982	test1: 0.7080781	best: 0.7080781 (190)	total: 19.3s	remaining: 3m 2s
# 200:	test: 0.7168115	test1: 0.7081820	best: 0.7081820 (200)	total: 20.2s	remaining: 3m 1s
# 210:	test: 0.7174177	test1: 0.7083426	best: 0.7084868 (207)	total: 21.2s	remaining: 3m
# 220:	test: 0.7182083	test1: 0.7095175	best: 0.7095175 (220)	total: 22.4s	remaining: 3m
# 230:	test: 0.7187951	test1: 0.7101097	best: 0.7101726 (229)	total: 23.4s	remaining: 2m 59s
# 240:	test: 0.7197083	test1: 0.7109068	best: 0.7109068 (240)	total: 24.4s	remaining: 2m 57s
# 250:	test: 0.7199558	test1: 0.7112248	best: 0.7112248 (250)	total: 25.4s	remaining: 2m 56s
# 260:	test: 0.7206309	test1: 0.7113456	best: 0.7114562 (256)	total: 26.4s	remaining: 2m 55s
# 270:	test: 0.7210070	test1: 0.7118585	best: 0.7118585 (270)	total: 27.3s	remaining: 2m 54s
# 280:	test: 0.7216183	test1: 0.7122539	best: 0.7122539 (280)	total: 28.2s	remaining: 2m 52s
# 290:	test: 0.7220725	test1: 0.7130583	best: 0.7130663 (288)	total: 29.1s	remaining: 2m 51s
# 300:	test: 0.7226908	test1: 0.7131817	best: 0.7132121 (296)	total: 30.1s	remaining: 2m 49s
# 310:	test: 0.7234738	test1: 0.7134579	best: 0.7135436 (304)	total: 31.1s	remaining: 2m 48s
# 320:	test: 0.7241197	test1: 0.7139269	best: 0.7139269 (320)	total: 32.1s	remaining: 2m 47s
# 330:	test: 0.7248539	test1: 0.7135766	best: 0.7139269 (320)	total: 33.1s	remaining: 2m 47s
# 340:	test: 0.7255547	test1: 0.7140444	best: 0.7141770 (338)	total: 34.1s	remaining: 2m 45s
# 350:	test: 0.7259234	test1: 0.7142166	best: 0.7142681 (349)	total: 35.1s	remaining: 2m 44s
# 360:	test: 0.7265793	test1: 0.7145662	best: 0.7146128 (358)	total: 36.1s	remaining: 2m 43s
# 370:	test: 0.7269097	test1: 0.7149189	best: 0.7149189 (370)	total: 37.1s	remaining: 2m 43s
# 380:	test: 0.7272363	test1: 0.7152042	best: 0.7152042 (380)	total: 38.1s	remaining: 2m 42s
# 390:	test: 0.7275649	test1: 0.7154773	best: 0.7154773 (390)	total: 39.1s	remaining: 2m 41s
# 400:	test: 0.7280055	test1: 0.7157378	best: 0.7157422 (399)	total: 40.1s	remaining: 2m 40s
# 410:	test: 0.7285047	test1: 0.7161643	best: 0.7162214 (408)	total: 41.1s	remaining: 2m 39s
# 420:	test: 0.7287993	test1: 0.7163335	best: 0.7163515 (417)	total: 42.1s	remaining: 2m 37s
# 430:	test: 0.7293128	test1: 0.7165931	best: 0.7166185 (429)	total: 43.1s	remaining: 2m 36s
# 440:	test: 0.7296210	test1: 0.7168175	best: 0.7168832 (438)	total: 44s	remaining: 2m 35s
# 450:	test: 0.7299823	test1: 0.7171919	best: 0.7171919 (450)	total: 45s	remaining: 2m 34s
# 460:	test: 0.7306371	test1: 0.7174973	best: 0.7174973 (460)	total: 46s	remaining: 2m 33s
# 470:	test: 0.7309958	test1: 0.7176698	best: 0.7177012 (469)	total: 47s	remaining: 2m 32s
# 480:	test: 0.7314565	test1: 0.7177553	best: 0.7178055 (476)	total: 47.9s	remaining: 2m 31s
# 490:	test: 0.7320395	test1: 0.7177946	best: 0.7178900 (488)	total: 48.9s	remaining: 2m 30s
# 500:	test: 0.7322736	test1: 0.7180562	best: 0.7180562 (500)	total: 49.9s	remaining: 2m 29s
# 510:	test: 0.7325307	test1: 0.7180745	best: 0.7182666 (509)	total: 50.9s	remaining: 2m 28s
# 520:	test: 0.7328961	test1: 0.7182436	best: 0.7182666 (509)	total: 51.9s	remaining: 2m 27s
# 530:	test: 0.7332727	test1: 0.7182519	best: 0.7183686 (521)	total: 52.9s	remaining: 2m 26s
# 540:	test: 0.7335613	test1: 0.7183721	best: 0.7183721 (540)	total: 53.8s	remaining: 2m 25s
# 550:	test: 0.7339811	test1: 0.7184800	best: 0.7185412 (545)	total: 54.8s	remaining: 2m 24s
# 560:	test: 0.7343648	test1: 0.7183966	best: 0.7185470 (556)	total: 55.7s	remaining: 2m 22s
# 570:	test: 0.7346994	test1: 0.7187064	best: 0.7187064 (570)	total: 56.6s	remaining: 2m 21s
# 580:	test: 0.7350967	test1: 0.7188829	best: 0.7188865 (577)	total: 57.6s	remaining: 2m 20s
# 590:	test: 0.7354780	test1: 0.7187566	best: 0.7189020 (582)	total: 58.6s	remaining: 2m 19s
# 600:	test: 0.7358080	test1: 0.7189068	best: 0.7189068 (600)	total: 59.5s	remaining: 2m 18s
# 610:	test: 0.7360856	test1: 0.7191070	best: 0.7191070 (610)	total: 1m	remaining: 2m 17s
# 620:	test: 0.7362960	test1: 0.7188973	best: 0.7191404 (614)	total: 1m 1s	remaining: 2m 16s
# 630:	test: 0.7365825	test1: 0.7189734	best: 0.7191404 (614)	total: 1m 2s	remaining: 2m 15s
# 640:	test: 0.7368214	test1: 0.7191248	best: 0.7192316 (639)	total: 1m 3s	remaining: 2m 14s
# 650:	test: 0.7371539	test1: 0.7192175	best: 0.7192316 (639)	total: 1m 4s	remaining: 2m 13s
# 660:	test: 0.7373316	test1: 0.7191346	best: 0.7192316 (639)	total: 1m 5s	remaining: 2m 12s
# 670:	test: 0.7375427	test1: 0.7192658	best: 0.7193104 (668)	total: 1m 6s	remaining: 2m 11s
# 680:	test: 0.7378526	test1: 0.7193059	best: 0.7193104 (668)	total: 1m 7s	remaining: 2m 10s
# 690:	test: 0.7380271	test1: 0.7192909	best: 0.7193277 (687)	total: 1m 8s	remaining: 2m 9s
# 700:	test: 0.7383403	test1: 0.7193317	best: 0.7193886 (695)	total: 1m 9s	remaining: 2m 8s
# 710:	test: 0.7385492	test1: 0.7196794	best: 0.7196885 (709)	total: 1m 10s	remaining: 2m 7s
# 720:	test: 0.7388193	test1: 0.7196792	best: 0.7196904 (714)	total: 1m 11s	remaining: 2m 6s
# 730:	test: 0.7390285	test1: 0.7196115	best: 0.7196904 (714)	total: 1m 12s	remaining: 2m 5s
# 740:	test: 0.7392432	test1: 0.7198518	best: 0.7198518 (740)	total: 1m 13s	remaining: 2m 4s
# 750:	test: 0.7395938	test1: 0.7199578	best: 0.7200281 (749)	total: 1m 14s	remaining: 2m 3s
# 760:	test: 0.7397641	test1: 0.7199933	best: 0.7200281 (749)	total: 1m 15s	remaining: 2m 2s
# 770:	test: 0.7401752	test1: 0.7200343	best: 0.7201426 (768)	total: 1m 16s	remaining: 2m 1s
# 780:	test: 0.7404687	test1: 0.7201223	best: 0.7201516 (776)	total: 1m 17s	remaining: 2m
# 790:	test: 0.7405733	test1: 0.7205159	best: 0.7205159 (790)	total: 1m 18s	remaining: 1m 59s
# 800:	test: 0.7409096	test1: 0.7205074	best: 0.7205423 (793)	total: 1m 19s	remaining: 1m 58s
# 810:	test: 0.7411187	test1: 0.7206675	best: 0.7206675 (810)	total: 1m 20s	remaining: 1m 57s
# 820:	test: 0.7414170	test1: 0.7206295	best: 0.7206675 (810)	total: 1m 21s	remaining: 1m 56s
# 830:	test: 0.7416981	test1: 0.7206070	best: 0.7206778 (826)	total: 1m 22s	remaining: 1m 55s
# 840:	test: 0.7419054	test1: 0.7206502	best: 0.7206778 (826)	total: 1m 22s	remaining: 1m 54s
# 850:	test: 0.7422323	test1: 0.7208465	best: 0.7208484 (849)	total: 1m 23s	remaining: 1m 53s
# 860:	test: 0.7424373	test1: 0.7210254	best: 0.7210325 (857)	total: 1m 24s	remaining: 1m 52s
# 870:	test: 0.7427373	test1: 0.7210523	best: 0.7211136 (867)	total: 1m 25s	remaining: 1m 51s
# 880:	test: 0.7430402	test1: 0.7210552	best: 0.7211136 (867)	total: 1m 26s	remaining: 1m 50s
# 890:	test: 0.7432320	test1: 0.7210184	best: 0.7211354 (883)	total: 1m 27s	remaining: 1m 49s
# 900:	test: 0.7433949	test1: 0.7211687	best: 0.7213110 (896)	total: 1m 28s	remaining: 1m 48s
# 910:	test: 0.7437403	test1: 0.7212308	best: 0.7213223 (909)	total: 1m 29s	remaining: 1m 47s
# 920:	test: 0.7438893	test1: 0.7211859	best: 0.7213223 (909)	total: 1m 30s	remaining: 1m 46s
# 930:	test: 0.7442164	test1: 0.7211960	best: 0.7213223 (909)	total: 1m 31s	remaining: 1m 45s
# 940:	test: 0.7444673	test1: 0.7211900	best: 0.7213223 (909)	total: 1m 32s	remaining: 1m 44s
# 950:	test: 0.7446176	test1: 0.7213102	best: 0.7213341 (944)	total: 1m 33s	remaining: 1m 43s
# 960:	test: 0.7447767	test1: 0.7213274	best: 0.7213536 (959)	total: 1m 34s	remaining: 1m 42s
# 970:	test: 0.7449901	test1: 0.7212787	best: 0.7213536 (959)	total: 1m 35s	remaining: 1m 41s
# 980:	test: 0.7452039	test1: 0.7213356	best: 0.7213536 (959)	total: 1m 36s	remaining: 1m 40s
# 990:	test: 0.7454340	test1: 0.7214053	best: 0.7214053 (990)	total: 1m 37s	remaining: 1m 39s
# 1000:	test: 0.7456573	test1: 0.7214711	best: 0.7215842 (998)	total: 1m 38s	remaining: 1m 38s
# 1010:	test: 0.7459362	test1: 0.7215059	best: 0.7215842 (998)	total: 1m 39s	remaining: 1m 37s
# 1020:	test: 0.7460900	test1: 0.7215792	best: 0.7215842 (998)	total: 1m 40s	remaining: 1m 36s
# 1030:	test: 0.7463087	test1: 0.7216637	best: 0.7216742 (1029)	total: 1m 41s	remaining: 1m 35s
# 1040:	test: 0.7464483	test1: 0.7216951	best: 0.7217086 (1036)	total: 1m 42s	remaining: 1m 34s
# 1050:	test: 0.7467041	test1: 0.7218847	best: 0.7218847 (1050)	total: 1m 43s	remaining: 1m 33s
# 1060:	test: 0.7469823	test1: 0.7217915	best: 0.7219087 (1051)	total: 1m 44s	remaining: 1m 32s
# 1070:	test: 0.7471445	test1: 0.7219125	best: 0.7219125 (1070)	total: 1m 45s	remaining: 1m 31s
# 1080:	test: 0.7473763	test1: 0.7219171	best: 0.7219404 (1073)	total: 1m 46s	remaining: 1m 30s
# 1090:	test: 0.7476294	test1: 0.7218654	best: 0.7219404 (1073)	total: 1m 47s	remaining: 1m 29s
# 1100:	test: 0.7477776	test1: 0.7217688	best: 0.7219404 (1073)	total: 1m 48s	remaining: 1m 28s
# 1110:	test: 0.7478415	test1: 0.7218587	best: 0.7219404 (1073)	total: 1m 49s	remaining: 1m 27s
# 1120:	test: 0.7480232	test1: 0.7218831	best: 0.7219404 (1073)	total: 1m 50s	remaining: 1m 26s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7219404129
# bestIteration = 1073
#
# Shrink model to first 1074 iterations.
# Fold 1, Valid score = 0.72194
# 0:	test: 0.5870332	test1: 0.5796510	best: 0.5796510 (0)	total: 112ms	remaining: 3m 44s
# 10:	test: 0.6976021	test1: 0.6975791	best: 0.6989064 (9)	total: 1.13s	remaining: 3m 24s
# 20:	test: 0.7020362	test1: 0.7014958	best: 0.7014958 (20)	total: 2.14s	remaining: 3m 21s
# 30:	test: 0.7035766	test1: 0.7036185	best: 0.7038149 (29)	total: 3.17s	remaining: 3m 21s
# 40:	test: 0.7053163	test1: 0.7037698	best: 0.7048624 (37)	total: 4.18s	remaining: 3m 20s
# 50:	test: 0.7063385	test1: 0.7046989	best: 0.7048624 (37)	total: 5.2s	remaining: 3m 18s
# 60:	test: 0.7070464	test1: 0.7053405	best: 0.7053405 (60)	total: 6.21s	remaining: 3m 17s
# 70:	test: 0.7080657	test1: 0.7058537	best: 0.7059752 (68)	total: 7.31s	remaining: 3m 18s
# 80:	test: 0.7083729	test1: 0.7061793	best: 0.7062403 (78)	total: 8.45s	remaining: 3m 20s
# 90:	test: 0.7083891	test1: 0.7063283	best: 0.7063300 (88)	total: 9.58s	remaining: 3m 20s
# 100:	test: 0.7089041	test1: 0.7063712	best: 0.7065907 (95)	total: 10.6s	remaining: 3m 18s
# 110:	test: 0.7088361	test1: 0.7067850	best: 0.7067850 (110)	total: 11.6s	remaining: 3m 17s
# 120:	test: 0.7097130	test1: 0.7073040	best: 0.7073040 (120)	total: 12.6s	remaining: 3m 15s
# 130:	test: 0.7098563	test1: 0.7078397	best: 0.7078397 (130)	total: 13.7s	remaining: 3m 14s
# 140:	test: 0.7103257	test1: 0.7083814	best: 0.7084993 (137)	total: 14.7s	remaining: 3m 13s
# 150:	test: 0.7107724	test1: 0.7086411	best: 0.7089560 (147)	total: 15.7s	remaining: 3m 12s
# 160:	test: 0.7121953	test1: 0.7102218	best: 0.7102218 (160)	total: 16.7s	remaining: 3m 10s
# 170:	test: 0.7128927	test1: 0.7105126	best: 0.7106109 (167)	total: 17.7s	remaining: 3m 8s
# 180:	test: 0.7135172	test1: 0.7114956	best: 0.7114956 (180)	total: 18.6s	remaining: 3m 6s
# 190:	test: 0.7142761	test1: 0.7121969	best: 0.7121969 (190)	total: 19.5s	remaining: 3m 5s
# 200:	test: 0.7146034	test1: 0.7120980	best: 0.7123858 (193)	total: 20.6s	remaining: 3m 4s
# 210:	test: 0.7154669	test1: 0.7129545	best: 0.7129602 (205)	total: 21.5s	remaining: 3m 2s
# 220:	test: 0.7159846	test1: 0.7137902	best: 0.7138321 (219)	total: 22.5s	remaining: 3m 1s
# 230:	test: 0.7166275	test1: 0.7138476	best: 0.7140153 (222)	total: 23.5s	remaining: 2m 59s
# 240:	test: 0.7172722	test1: 0.7140257	best: 0.7141731 (235)	total: 24.4s	remaining: 2m 58s
# 250:	test: 0.7179353	test1: 0.7146199	best: 0.7146199 (250)	total: 25.4s	remaining: 2m 57s
# 260:	test: 0.7182622	test1: 0.7148333	best: 0.7148333 (260)	total: 26.4s	remaining: 2m 55s
# 270:	test: 0.7190081	test1: 0.7150574	best: 0.7151210 (269)	total: 27.4s	remaining: 2m 54s
# 280:	test: 0.7199292	test1: 0.7156806	best: 0.7156806 (280)	total: 28.4s	remaining: 2m 53s
# 290:	test: 0.7204228	test1: 0.7162223	best: 0.7162751 (288)	total: 29.3s	remaining: 2m 52s
# 300:	test: 0.7211126	test1: 0.7167653	best: 0.7168258 (296)	total: 30.3s	remaining: 2m 50s
# 310:	test: 0.7217205	test1: 0.7172320	best: 0.7172377 (304)	total: 31.3s	remaining: 2m 49s
# 320:	test: 0.7223828	test1: 0.7179112	best: 0.7179618 (318)	total: 32.3s	remaining: 2m 49s
# 330:	test: 0.7227640	test1: 0.7183719	best: 0.7184569 (328)	total: 33.3s	remaining: 2m 47s
# 340:	test: 0.7235564	test1: 0.7187121	best: 0.7189441 (338)	total: 34.3s	remaining: 2m 46s
# 350:	test: 0.7240493	test1: 0.7191709	best: 0.7191709 (350)	total: 35.2s	remaining: 2m 45s
# 360:	test: 0.7245270	test1: 0.7195463	best: 0.7195718 (358)	total: 36.2s	remaining: 2m 44s
# 370:	test: 0.7251002	test1: 0.7200826	best: 0.7200826 (370)	total: 37.1s	remaining: 2m 43s
# 380:	test: 0.7259149	test1: 0.7204344	best: 0.7204452 (379)	total: 38.1s	remaining: 2m 41s
# 390:	test: 0.7263935	test1: 0.7209315	best: 0.7209315 (390)	total: 39.1s	remaining: 2m 40s
# 400:	test: 0.7269011	test1: 0.7210217	best: 0.7210217 (400)	total: 40.1s	remaining: 2m 39s
# 410:	test: 0.7272716	test1: 0.7211097	best: 0.7212428 (407)	total: 41s	remaining: 2m 38s
# 420:	test: 0.7276491	test1: 0.7214923	best: 0.7216694 (419)	total: 42s	remaining: 2m 37s
# 430:	test: 0.7280634	test1: 0.7218212	best: 0.7219043 (429)	total: 43s	remaining: 2m 36s
# 440:	test: 0.7285479	test1: 0.7219546	best: 0.7220485 (432)	total: 44s	remaining: 2m 35s
# 450:	test: 0.7289402	test1: 0.7217203	best: 0.7220485 (432)	total: 44.9s	remaining: 2m 34s
# 460:	test: 0.7293745	test1: 0.7216227	best: 0.7220485 (432)	total: 45.9s	remaining: 2m 33s
# 470:	test: 0.7296535	test1: 0.7219230	best: 0.7220485 (432)	total: 46.9s	remaining: 2m 32s
# 480:	test: 0.7302103	test1: 0.7219971	best: 0.7220792 (472)	total: 47.9s	remaining: 2m 31s
# 490:	test: 0.7304531	test1: 0.7225940	best: 0.7225940 (490)	total: 48.8s	remaining: 2m 29s
# 500:	test: 0.7308045	test1: 0.7226670	best: 0.7226670 (500)	total: 49.7s	remaining: 2m 28s
# 510:	test: 0.7311275	test1: 0.7232316	best: 0.7232316 (510)	total: 50.7s	remaining: 2m 27s
# 520:	test: 0.7314379	test1: 0.7234086	best: 0.7234685 (519)	total: 51.7s	remaining: 2m 26s
# 530:	test: 0.7317762	test1: 0.7237034	best: 0.7238251 (527)	total: 52.6s	remaining: 2m 25s
# 540:	test: 0.7319875	test1: 0.7239802	best: 0.7240858 (534)	total: 53.6s	remaining: 2m 24s
# 550:	test: 0.7323995	test1: 0.7241313	best: 0.7241948 (545)	total: 54.6s	remaining: 2m 23s
# 560:	test: 0.7326685	test1: 0.7240808	best: 0.7241948 (545)	total: 55.6s	remaining: 2m 22s
# 570:	test: 0.7331302	test1: 0.7240386	best: 0.7241948 (545)	total: 56.6s	remaining: 2m 21s
# 580:	test: 0.7335115	test1: 0.7241458	best: 0.7242225 (577)	total: 57.6s	remaining: 2m 20s
# 590:	test: 0.7340006	test1: 0.7242893	best: 0.7243840 (588)	total: 58.5s	remaining: 2m 19s
# 600:	test: 0.7342793	test1: 0.7245096	best: 0.7245427 (599)	total: 59.6s	remaining: 2m 18s
# 610:	test: 0.7345879	test1: 0.7248491	best: 0.7248491 (610)	total: 1m	remaining: 2m 17s
# 620:	test: 0.7350210	test1: 0.7249830	best: 0.7249830 (620)	total: 1m 1s	remaining: 2m 16s
# 630:	test: 0.7353541	test1: 0.7252164	best: 0.7252615 (629)	total: 1m 2s	remaining: 2m 15s
# 640:	test: 0.7356720	test1: 0.7252714	best: 0.7252898 (632)	total: 1m 3s	remaining: 2m 14s
# 650:	test: 0.7360393	test1: 0.7250260	best: 0.7252898 (632)	total: 1m 4s	remaining: 2m 13s
# 660:	test: 0.7364992	test1: 0.7251044	best: 0.7252898 (632)	total: 1m 5s	remaining: 2m 12s
# 670:	test: 0.7367153	test1: 0.7252754	best: 0.7253008 (668)	total: 1m 6s	remaining: 2m 11s
# 680:	test: 0.7370070	test1: 0.7253924	best: 0.7253924 (680)	total: 1m 7s	remaining: 2m 10s
# 690:	test: 0.7372993	test1: 0.7255150	best: 0.7255245 (688)	total: 1m 8s	remaining: 2m 9s
# 700:	test: 0.7376482	test1: 0.7255921	best: 0.7255921 (700)	total: 1m 9s	remaining: 2m 8s
# 710:	test: 0.7378369	test1: 0.7255575	best: 0.7256163 (707)	total: 1m 10s	remaining: 2m 7s
# 720:	test: 0.7380053	test1: 0.7253046	best: 0.7256163 (707)	total: 1m 11s	remaining: 2m 6s
# 730:	test: 0.7382912	test1: 0.7256792	best: 0.7257447 (728)	total: 1m 12s	remaining: 2m 5s
# 740:	test: 0.7386629	test1: 0.7258531	best: 0.7258531 (740)	total: 1m 13s	remaining: 2m 4s
# 750:	test: 0.7389277	test1: 0.7260086	best: 0.7260086 (750)	total: 1m 14s	remaining: 2m 3s
# 760:	test: 0.7391130	test1: 0.7259355	best: 0.7260086 (750)	total: 1m 15s	remaining: 2m 2s
# 770:	test: 0.7393684	test1: 0.7260851	best: 0.7260851 (770)	total: 1m 16s	remaining: 2m 1s
# 780:	test: 0.7397117	test1: 0.7260964	best: 0.7261183 (772)	total: 1m 17s	remaining: 2m
# 790:	test: 0.7399536	test1: 0.7259726	best: 0.7261183 (772)	total: 1m 18s	remaining: 1m 59s
# 800:	test: 0.7402939	test1: 0.7259431	best: 0.7261183 (772)	total: 1m 19s	remaining: 1m 58s
# 810:	test: 0.7405117	test1: 0.7262173	best: 0.7262173 (810)	total: 1m 20s	remaining: 1m 57s
# 820:	test: 0.7407151	test1: 0.7262360	best: 0.7263220 (811)	total: 1m 21s	remaining: 1m 56s
# 830:	test: 0.7408598	test1: 0.7263820	best: 0.7263826 (829)	total: 1m 22s	remaining: 1m 55s
# 840:	test: 0.7411521	test1: 0.7263862	best: 0.7263862 (840)	total: 1m 23s	remaining: 1m 54s
# 850:	test: 0.7413558	test1: 0.7264686	best: 0.7265932 (843)	total: 1m 24s	remaining: 1m 53s
# 860:	test: 0.7416275	test1: 0.7264906	best: 0.7265932 (843)	total: 1m 25s	remaining: 1m 52s
# 870:	test: 0.7418407	test1: 0.7263131	best: 0.7265932 (843)	total: 1m 26s	remaining: 1m 51s
# 880:	test: 0.7420203	test1: 0.7262556	best: 0.7265932 (843)	total: 1m 27s	remaining: 1m 50s
# 890:	test: 0.7422960	test1: 0.7262963	best: 0.7265932 (843)	total: 1m 28s	remaining: 1m 49s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.726593228
# bestIteration = 843
#
# Shrink model to first 844 iterations.
# Fold 2, Valid score = 0.72659
# 0:	test: 0.5901509	test1: 0.5960321	best: 0.5960321 (0)	total: 105ms	remaining: 3m 29s
# 10:	test: 0.6985443	test1: 0.6982714	best: 0.6982714 (10)	total: 1.15s	remaining: 3m 27s
# 20:	test: 0.7017296	test1: 0.7023509	best: 0.7024615 (17)	total: 2.15s	remaining: 3m 22s
# 30:	test: 0.7035493	test1: 0.7040296	best: 0.7043729 (27)	total: 3.18s	remaining: 3m 22s
# 40:	test: 0.7050048	test1: 0.7057310	best: 0.7057310 (40)	total: 4.19s	remaining: 3m 20s
# 50:	test: 0.7062782	test1: 0.7071693	best: 0.7071693 (50)	total: 5.2s	remaining: 3m 18s
# 60:	test: 0.7071490	test1: 0.7080046	best: 0.7081748 (59)	total: 6.19s	remaining: 3m 16s
# 70:	test: 0.7077090	test1: 0.7084396	best: 0.7084396 (70)	total: 7.18s	remaining: 3m 15s
# 80:	test: 0.7081904	test1: 0.7086428	best: 0.7086797 (79)	total: 8.19s	remaining: 3m 14s
# 90:	test: 0.7083666	test1: 0.7087519	best: 0.7090524 (87)	total: 9.18s	remaining: 3m 12s
# 100:	test: 0.7087518	test1: 0.7096628	best: 0.7096628 (100)	total: 10.2s	remaining: 3m 11s
# 110:	test: 0.7092269	test1: 0.7096573	best: 0.7096806 (107)	total: 11.2s	remaining: 3m 10s
# 120:	test: 0.7098893	test1: 0.7102498	best: 0.7103114 (118)	total: 12.2s	remaining: 3m 9s
# 130:	test: 0.7099308	test1: 0.7102949	best: 0.7103114 (118)	total: 13.2s	remaining: 3m 8s
# 140:	test: 0.7101475	test1: 0.7100487	best: 0.7103207 (138)	total: 14.2s	remaining: 3m 7s
# 150:	test: 0.7103223	test1: 0.7101051	best: 0.7104379 (147)	total: 15.2s	remaining: 3m 6s
# 160:	test: 0.7109909	test1: 0.7106623	best: 0.7106623 (160)	total: 16.2s	remaining: 3m 5s
# 170:	test: 0.7117674	test1: 0.7113670	best: 0.7113670 (170)	total: 17.2s	remaining: 3m 4s
# 180:	test: 0.7131138	test1: 0.7128796	best: 0.7128796 (180)	total: 18.1s	remaining: 3m 1s
# 190:	test: 0.7140741	test1: 0.7138452	best: 0.7138452 (190)	total: 19.1s	remaining: 3m
# 200:	test: 0.7150624	test1: 0.7143099	best: 0.7144355 (198)	total: 20s	remaining: 2m 58s
# 210:	test: 0.7159216	test1: 0.7152911	best: 0.7153149 (209)	total: 21s	remaining: 2m 57s
# 220:	test: 0.7167333	test1: 0.7160174	best: 0.7160174 (220)	total: 22s	remaining: 2m 56s
# 230:	test: 0.7172228	test1: 0.7163737	best: 0.7165092 (229)	total: 22.9s	remaining: 2m 55s
# 240:	test: 0.7178063	test1: 0.7170337	best: 0.7170496 (239)	total: 23.9s	remaining: 2m 54s
# 250:	test: 0.7182737	test1: 0.7178514	best: 0.7178514 (250)	total: 24.9s	remaining: 2m 53s
# 260:	test: 0.7186592	test1: 0.7188970	best: 0.7189171 (259)	total: 25.9s	remaining: 2m 52s
# 270:	test: 0.7191283	test1: 0.7192907	best: 0.7192907 (270)	total: 26.9s	remaining: 2m 51s
# 280:	test: 0.7195254	test1: 0.7198776	best: 0.7198776 (280)	total: 27.9s	remaining: 2m 50s
# 290:	test: 0.7199568	test1: 0.7199411	best: 0.7201953 (285)	total: 28.9s	remaining: 2m 49s
# 300:	test: 0.7206278	test1: 0.7204804	best: 0.7204804 (300)	total: 29.9s	remaining: 2m 48s
# 310:	test: 0.7214312	test1: 0.7208868	best: 0.7208868 (310)	total: 30.9s	remaining: 2m 47s
# 320:	test: 0.7220615	test1: 0.7210864	best: 0.7210864 (320)	total: 31.9s	remaining: 2m 46s
# 330:	test: 0.7225475	test1: 0.7214456	best: 0.7214456 (330)	total: 32.9s	remaining: 2m 45s
# 340:	test: 0.7229771	test1: 0.7216664	best: 0.7217644 (337)	total: 33.9s	remaining: 2m 44s
# 350:	test: 0.7235876	test1: 0.7220453	best: 0.7220453 (350)	total: 34.8s	remaining: 2m 43s
# 360:	test: 0.7240585	test1: 0.7223042	best: 0.7224030 (358)	total: 35.9s	remaining: 2m 42s
# 370:	test: 0.7245873	test1: 0.7234198	best: 0.7234198 (370)	total: 36.9s	remaining: 2m 41s
# 380:	test: 0.7252031	test1: 0.7237143	best: 0.7238104 (376)	total: 37.9s	remaining: 2m 40s
# 390:	test: 0.7256810	test1: 0.7243461	best: 0.7244763 (389)	total: 38.9s	remaining: 2m 39s
# 400:	test: 0.7261152	test1: 0.7242016	best: 0.7244763 (389)	total: 39.9s	remaining: 2m 39s
# 410:	test: 0.7266808	test1: 0.7245778	best: 0.7246297 (402)	total: 40.9s	remaining: 2m 38s
# 420:	test: 0.7272690	test1: 0.7251481	best: 0.7251481 (420)	total: 41.8s	remaining: 2m 36s
# 430:	test: 0.7277819	test1: 0.7252502	best: 0.7252502 (430)	total: 42.8s	remaining: 2m 35s
# 440:	test: 0.7281053	test1: 0.7254536	best: 0.7254536 (440)	total: 43.8s	remaining: 2m 34s
# 450:	test: 0.7284996	test1: 0.7256374	best: 0.7257329 (449)	total: 44.8s	remaining: 2m 33s
# 460:	test: 0.7289003	test1: 0.7258525	best: 0.7258902 (453)	total: 45.7s	remaining: 2m 32s
# 470:	test: 0.7292460	test1: 0.7260166	best: 0.7260166 (470)	total: 46.7s	remaining: 2m 31s
# 480:	test: 0.7295085	test1: 0.7260490	best: 0.7261732 (478)	total: 47.7s	remaining: 2m 30s
# 490:	test: 0.7298878	test1: 0.7260787	best: 0.7261958 (482)	total: 48.6s	remaining: 2m 29s
# 500:	test: 0.7302552	test1: 0.7263683	best: 0.7264246 (499)	total: 49.5s	remaining: 2m 28s
# 510:	test: 0.7305829	test1: 0.7264138	best: 0.7264262 (507)	total: 50.5s	remaining: 2m 27s
# 520:	test: 0.7308268	test1: 0.7262941	best: 0.7264615 (517)	total: 51.5s	remaining: 2m 26s
# 530:	test: 0.7312208	test1: 0.7266508	best: 0.7266615 (529)	total: 52.5s	remaining: 2m 25s
# 540:	test: 0.7315462	test1: 0.7268820	best: 0.7268820 (540)	total: 53.4s	remaining: 2m 23s
# 550:	test: 0.7318001	test1: 0.7269792	best: 0.7269792 (550)	total: 54.3s	remaining: 2m 22s
# 560:	test: 0.7322005	test1: 0.7271868	best: 0.7272895 (558)	total: 55.3s	remaining: 2m 21s
# 570:	test: 0.7326857	test1: 0.7275295	best: 0.7275295 (570)	total: 56.3s	remaining: 2m 20s
# 580:	test: 0.7329289	test1: 0.7277811	best: 0.7277889 (579)	total: 57.2s	remaining: 2m 19s
# 590:	test: 0.7331743	test1: 0.7277437	best: 0.7278648 (582)	total: 58.2s	remaining: 2m 18s
# 600:	test: 0.7334130	test1: 0.7281155	best: 0.7281293 (599)	total: 59.1s	remaining: 2m 17s
# 610:	test: 0.7338029	test1: 0.7283017	best: 0.7283451 (604)	total: 1m	remaining: 2m 16s
# 620:	test: 0.7341527	test1: 0.7283539	best: 0.7283539 (620)	total: 1m 1s	remaining: 2m 15s
# 630:	test: 0.7344685	test1: 0.7284902	best: 0.7286009 (627)	total: 1m 2s	remaining: 2m 14s
# 640:	test: 0.7346884	test1: 0.7288191	best: 0.7288191 (640)	total: 1m 3s	remaining: 2m 13s
# 650:	test: 0.7349543	test1: 0.7289876	best: 0.7289898 (649)	total: 1m 3s	remaining: 2m 12s
# 660:	test: 0.7353302	test1: 0.7288517	best: 0.7289898 (649)	total: 1m 4s	remaining: 2m 11s
# 670:	test: 0.7354908	test1: 0.7292261	best: 0.7292261 (670)	total: 1m 5s	remaining: 2m 10s
# 680:	test: 0.7356919	test1: 0.7294032	best: 0.7294757 (679)	total: 1m 6s	remaining: 2m 9s
# 690:	test: 0.7360473	test1: 0.7298147	best: 0.7298304 (689)	total: 1m 7s	remaining: 2m 8s
# 700:	test: 0.7363391	test1: 0.7296541	best: 0.7298603 (691)	total: 1m 8s	remaining: 2m 7s
# 710:	test: 0.7366030	test1: 0.7296896	best: 0.7298603 (691)	total: 1m 9s	remaining: 2m 6s
# 720:	test: 0.7367948	test1: 0.7296802	best: 0.7298603 (691)	total: 1m 10s	remaining: 2m 5s
# 730:	test: 0.7370834	test1: 0.7297406	best: 0.7298603 (691)	total: 1m 11s	remaining: 2m 4s
# 740:	test: 0.7373554	test1: 0.7299262	best: 0.7299262 (740)	total: 1m 12s	remaining: 2m 3s
# 750:	test: 0.7376026	test1: 0.7295805	best: 0.7299262 (740)	total: 1m 13s	remaining: 2m 2s
# 760:	test: 0.7377268	test1: 0.7297522	best: 0.7299262 (740)	total: 1m 14s	remaining: 2m 1s
# 770:	test: 0.7380686	test1: 0.7297362	best: 0.7299262 (740)	total: 1m 15s	remaining: 2m
# 780:	test: 0.7383077	test1: 0.7296658	best: 0.7299262 (740)	total: 1m 16s	remaining: 1m 59s
# 790:	test: 0.7386633	test1: 0.7298611	best: 0.7299873 (789)	total: 1m 17s	remaining: 1m 58s
# 800:	test: 0.7388055	test1: 0.7299557	best: 0.7301179 (798)	total: 1m 18s	remaining: 1m 57s
# 810:	test: 0.7390350	test1: 0.7299565	best: 0.7301179 (798)	total: 1m 19s	remaining: 1m 56s
# 820:	test: 0.7392185	test1: 0.7299765	best: 0.7301179 (798)	total: 1m 20s	remaining: 1m 55s
# 830:	test: 0.7394132	test1: 0.7300217	best: 0.7301179 (798)	total: 1m 21s	remaining: 1m 54s
# 840:	test: 0.7396807	test1: 0.7301933	best: 0.7302091 (839)	total: 1m 22s	remaining: 1m 53s
# 850:	test: 0.7397577	test1: 0.7299923	best: 0.7302377 (843)	total: 1m 23s	remaining: 1m 52s
# 860:	test: 0.7399541	test1: 0.7300781	best: 0.7302377 (843)	total: 1m 24s	remaining: 1m 51s
# 870:	test: 0.7401841	test1: 0.7298195	best: 0.7302377 (843)	total: 1m 25s	remaining: 1m 50s
# 880:	test: 0.7404111	test1: 0.7299011	best: 0.7302377 (843)	total: 1m 26s	remaining: 1m 49s
# 890:	test: 0.7406453	test1: 0.7300044	best: 0.7302377 (843)	total: 1m 27s	remaining: 1m 48s
# 900:	test: 0.7408988	test1: 0.7303267	best: 0.7303407 (899)	total: 1m 27s	remaining: 1m 47s
# 910:	test: 0.7410549	test1: 0.7303893	best: 0.7304153 (909)	total: 1m 28s	remaining: 1m 46s
# 920:	test: 0.7413630	test1: 0.7304641	best: 0.7305497 (913)	total: 1m 29s	remaining: 1m 45s
# 930:	test: 0.7416192	test1: 0.7306694	best: 0.7306694 (930)	total: 1m 30s	remaining: 1m 44s
# 940:	test: 0.7417556	test1: 0.7308486	best: 0.7308486 (940)	total: 1m 31s	remaining: 1m 43s
# 950:	test: 0.7419653	test1: 0.7309836	best: 0.7309836 (950)	total: 1m 32s	remaining: 1m 42s
# 960:	test: 0.7422622	test1: 0.7310982	best: 0.7311016 (957)	total: 1m 33s	remaining: 1m 41s
# 970:	test: 0.7425039	test1: 0.7310925	best: 0.7311340 (967)	total: 1m 34s	remaining: 1m 40s
# 980:	test: 0.7427257	test1: 0.7311722	best: 0.7311911 (975)	total: 1m 35s	remaining: 1m 39s
# 990:	test: 0.7430497	test1: 0.7309965	best: 0.7312562 (981)	total: 1m 36s	remaining: 1m 38s
# 1000:	test: 0.7432457	test1: 0.7312625	best: 0.7312625 (1000)	total: 1m 37s	remaining: 1m 37s
# 1010:	test: 0.7434676	test1: 0.7312384	best: 0.7313122 (1003)	total: 1m 38s	remaining: 1m 36s
# 1020:	test: 0.7436795	test1: 0.7312180	best: 0.7313122 (1003)	total: 1m 39s	remaining: 1m 35s
# 1030:	test: 0.7438201	test1: 0.7314438	best: 0.7314438 (1030)	total: 1m 40s	remaining: 1m 34s
# 1040:	test: 0.7441095	test1: 0.7314222	best: 0.7314525 (1035)	total: 1m 41s	remaining: 1m 33s
# 1050:	test: 0.7443110	test1: 0.7314866	best: 0.7314904 (1047)	total: 1m 42s	remaining: 1m 32s
# 1060:	test: 0.7445258	test1: 0.7317280	best: 0.7317428 (1058)	total: 1m 43s	remaining: 1m 31s
# 1070:	test: 0.7446977	test1: 0.7317441	best: 0.7319047 (1068)	total: 1m 44s	remaining: 1m 30s
# 1080:	test: 0.7450218	test1: 0.7317502	best: 0.7319047 (1068)	total: 1m 45s	remaining: 1m 29s
# 1090:	test: 0.7451847	test1: 0.7318705	best: 0.7319047 (1068)	total: 1m 46s	remaining: 1m 28s
# 1100:	test: 0.7453704	test1: 0.7319158	best: 0.7319334 (1093)	total: 1m 47s	remaining: 1m 27s
# 1110:	test: 0.7455695	test1: 0.7319058	best: 0.7319699 (1105)	total: 1m 48s	remaining: 1m 26s
# 1120:	test: 0.7458100	test1: 0.7320297	best: 0.7320482 (1118)	total: 1m 49s	remaining: 1m 25s
# 1130:	test: 0.7461351	test1: 0.7320747	best: 0.7320946 (1127)	total: 1m 50s	remaining: 1m 25s
# 1140:	test: 0.7464017	test1: 0.7320594	best: 0.7321122 (1135)	total: 1m 51s	remaining: 1m 24s
# 1150:	test: 0.7466071	test1: 0.7320531	best: 0.7321416 (1148)	total: 1m 52s	remaining: 1m 23s
# 1160:	test: 0.7468104	test1: 0.7320294	best: 0.7321416 (1148)	total: 1m 53s	remaining: 1m 22s
# 1170:	test: 0.7469775	test1: 0.7320714	best: 0.7321416 (1148)	total: 1m 54s	remaining: 1m 21s
# 1180:	test: 0.7472680	test1: 0.7320493	best: 0.7321542 (1171)	total: 1m 55s	remaining: 1m 20s
# 1190:	test: 0.7474625	test1: 0.7320746	best: 0.7321542 (1171)	total: 1m 56s	remaining: 1m 19s
# 1200:	test: 0.7475400	test1: 0.7321248	best: 0.7321542 (1171)	total: 1m 57s	remaining: 1m 18s
# 1210:	test: 0.7476973	test1: 0.7321605	best: 0.7321605 (1209)	total: 1m 58s	remaining: 1m 17s
# 1220:	test: 0.7478881	test1: 0.7320520	best: 0.7321898 (1216)	total: 1m 59s	remaining: 1m 16s
# 1230:	test: 0.7480194	test1: 0.7321396	best: 0.7321898 (1216)	total: 2m	remaining: 1m 15s
# 1240:	test: 0.7481388	test1: 0.7322145	best: 0.7322441 (1237)	total: 2m 1s	remaining: 1m 14s
# 1250:	test: 0.7483915	test1: 0.7322474	best: 0.7322474 (1250)	total: 2m 2s	remaining: 1m 13s
# 1260:	test: 0.7485404	test1: 0.7322634	best: 0.7322750 (1257)	total: 2m 3s	remaining: 1m 12s
# 1270:	test: 0.7486221	test1: 0.7322713	best: 0.7322756 (1266)	total: 2m 4s	remaining: 1m 11s
# 1280:	test: 0.7487749	test1: 0.7322729	best: 0.7323190 (1275)	total: 2m 5s	remaining: 1m 10s
# 1290:	test: 0.7488601	test1: 0.7321722	best: 0.7323214 (1285)	total: 2m 6s	remaining: 1m 9s
# 1300:	test: 0.7489571	test1: 0.7323170	best: 0.7323214 (1285)	total: 2m 7s	remaining: 1m 8s
# 1310:	test: 0.7491172	test1: 0.7322456	best: 0.7323484 (1301)	total: 2m 8s	remaining: 1m 7s
# 1320:	test: 0.7492056	test1: 0.7321974	best: 0.7323484 (1301)	total: 2m 9s	remaining: 1m 6s
# 1330:	test: 0.7494276	test1: 0.7322097	best: 0.7323484 (1301)	total: 2m 10s	remaining: 1m 5s
# 1340:	test: 0.7496164	test1: 0.7321442	best: 0.7323484 (1301)	total: 2m 10s	remaining: 1m 4s
# 1350:	test: 0.7497885	test1: 0.7323961	best: 0.7324683 (1345)	total: 2m 11s	remaining: 1m 3s
# 1360:	test: 0.7499057	test1: 0.7323880	best: 0.7324683 (1345)	total: 2m 12s	remaining: 1m 2s
# 1370:	test: 0.7500310	test1: 0.7324382	best: 0.7324683 (1345)	total: 2m 13s	remaining: 1m 1s
# 1380:	test: 0.7502499	test1: 0.7325429	best: 0.7325694 (1378)	total: 2m 14s	remaining: 1m
# 1390:	test: 0.7504356	test1: 0.7326079	best: 0.7326248 (1389)	total: 2m 15s	remaining: 59.3s
# 1400:	test: 0.7505790	test1: 0.7327260	best: 0.7327766 (1396)	total: 2m 16s	remaining: 58.3s
# 1410:	test: 0.7507613	test1: 0.7326936	best: 0.7327766 (1396)	total: 2m 17s	remaining: 57.2s
# 1420:	test: 0.7510210	test1: 0.7327381	best: 0.7328117 (1416)	total: 2m 18s	remaining: 56.2s
# 1430:	test: 0.7511281	test1: 0.7327292	best: 0.7328117 (1416)	total: 2m 18s	remaining: 55.3s
# 1440:	test: 0.7512787	test1: 0.7327796	best: 0.7328117 (1416)	total: 2m 19s	remaining: 54.3s
# 1450:	test: 0.7513195	test1: 0.7327844	best: 0.7328117 (1416)	total: 2m 20s	remaining: 53.3s
# 1460:	test: 0.7514601	test1: 0.7327127	best: 0.7328324 (1452)	total: 2m 21s	remaining: 52.4s
# 1470:	test: 0.7516197	test1: 0.7327474	best: 0.7328324 (1452)	total: 2m 22s	remaining: 51.4s
# 1480:	test: 0.7517004	test1: 0.7327896	best: 0.7328324 (1452)	total: 2m 23s	remaining: 50.4s
# 1490:	test: 0.7518588	test1: 0.7328122	best: 0.7328324 (1452)	total: 2m 24s	remaining: 49.4s
# 1500:	test: 0.7518834	test1: 0.7327184	best: 0.7328324 (1452)	total: 2m 25s	remaining: 48.4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7328323704
# bestIteration = 1452
#
# Shrink model to first 1453 iterations.
# Fold 3, Valid score = 0.73284
# 0:	test: 0.6595409	test1: 0.6504644	best: 0.6504644 (0)	total: 119ms	remaining: 3m 57s
# 10:	test: 0.7009050	test1: 0.6971595	best: 0.6971595 (10)	total: 1.23s	remaining: 3m 41s
# 20:	test: 0.7027085	test1: 0.6991332	best: 0.7000237 (19)	total: 2.35s	remaining: 3m 41s
# 30:	test: 0.7034192	test1: 0.7001410	best: 0.7002587 (29)	total: 3.37s	remaining: 3m 34s
# 40:	test: 0.7043805	test1: 0.7000679	best: 0.7003638 (34)	total: 4.39s	remaining: 3m 29s
# 50:	test: 0.7053054	test1: 0.7007605	best: 0.7007605 (50)	total: 5.48s	remaining: 3m 29s
# 60:	test: 0.7070427	test1: 0.7018562	best: 0.7019658 (59)	total: 6.6s	remaining: 3m 29s
# 70:	test: 0.7085961	test1: 0.7025069	best: 0.7025069 (70)	total: 7.63s	remaining: 3m 27s
# 80:	test: 0.7092150	test1: 0.7029684	best: 0.7029684 (80)	total: 8.66s	remaining: 3m 25s
# 90:	test: 0.7097728	test1: 0.7031326	best: 0.7032270 (87)	total: 9.64s	remaining: 3m 22s
# 100:	test: 0.7103111	test1: 0.7032649	best: 0.7033486 (96)	total: 10.6s	remaining: 3m 19s
# 110:	test: 0.7103708	test1: 0.7031034	best: 0.7035129 (105)	total: 11.6s	remaining: 3m 18s
# 120:	test: 0.7106000	test1: 0.7035103	best: 0.7035129 (105)	total: 12.8s	remaining: 3m 18s
# 130:	test: 0.7121750	test1: 0.7040354	best: 0.7040354 (130)	total: 13.8s	remaining: 3m 17s
# 140:	test: 0.7131190	test1: 0.7047516	best: 0.7047516 (140)	total: 14.9s	remaining: 3m 16s
# 150:	test: 0.7142429	test1: 0.7052819	best: 0.7054496 (148)	total: 15.9s	remaining: 3m 14s
# 160:	test: 0.7151422	test1: 0.7060894	best: 0.7061076 (158)	total: 17s	remaining: 3m 14s
# 170:	test: 0.7158631	test1: 0.7071510	best: 0.7071510 (170)	total: 18s	remaining: 3m 12s
# 180:	test: 0.7163239	test1: 0.7071972	best: 0.7074675 (175)	total: 19.1s	remaining: 3m 12s
# 190:	test: 0.7168856	test1: 0.7072215	best: 0.7074675 (175)	total: 20.2s	remaining: 3m 11s
# 200:	test: 0.7174624	test1: 0.7072532	best: 0.7076532 (195)	total: 21.3s	remaining: 3m 10s
# 210:	test: 0.7179960	test1: 0.7073343	best: 0.7076532 (195)	total: 22.4s	remaining: 3m 9s
# 220:	test: 0.7187014	test1: 0.7070765	best: 0.7076866 (216)	total: 23.5s	remaining: 3m 8s
# 230:	test: 0.7193441	test1: 0.7073585	best: 0.7076866 (216)	total: 24.5s	remaining: 3m 7s
# 240:	test: 0.7200446	test1: 0.7077483	best: 0.7078585 (239)	total: 25.6s	remaining: 3m 6s
# 250:	test: 0.7204156	test1: 0.7082716	best: 0.7082716 (250)	total: 26.7s	remaining: 3m 6s
# 260:	test: 0.7211414	test1: 0.7086754	best: 0.7086754 (260)	total: 27.8s	remaining: 3m 5s
# 270:	test: 0.7218185	test1: 0.7089960	best: 0.7089960 (270)	total: 28.8s	remaining: 3m 3s
# 280:	test: 0.7224853	test1: 0.7095625	best: 0.7095777 (274)	total: 29.8s	remaining: 3m 2s
# 290:	test: 0.7227444	test1: 0.7097919	best: 0.7098556 (288)	total: 30.8s	remaining: 3m 1s
# 300:	test: 0.7234334	test1: 0.7104869	best: 0.7104869 (300)	total: 31.8s	remaining: 2m 59s
# 310:	test: 0.7240725	test1: 0.7103983	best: 0.7105570 (301)	total: 32.8s	remaining: 2m 58s
# 320:	test: 0.7244991	test1: 0.7106405	best: 0.7106740 (314)	total: 33.8s	remaining: 2m 56s
# 330:	test: 0.7248642	test1: 0.7107704	best: 0.7107704 (330)	total: 34.8s	remaining: 2m 55s
# 340:	test: 0.7256040	test1: 0.7112777	best: 0.7112777 (340)	total: 35.8s	remaining: 2m 54s
# 350:	test: 0.7261174	test1: 0.7114625	best: 0.7114625 (350)	total: 36.8s	remaining: 2m 53s
# 360:	test: 0.7267249	test1: 0.7117435	best: 0.7117435 (360)	total: 37.9s	remaining: 2m 51s
# 370:	test: 0.7271305	test1: 0.7120424	best: 0.7120424 (370)	total: 39s	remaining: 2m 51s
# 380:	test: 0.7273257	test1: 0.7124061	best: 0.7124184 (379)	total: 40s	remaining: 2m 49s
# 390:	test: 0.7278665	test1: 0.7125102	best: 0.7125164 (389)	total: 41.1s	remaining: 2m 48s
# 400:	test: 0.7284577	test1: 0.7128278	best: 0.7128527 (399)	total: 42.1s	remaining: 2m 47s
# 410:	test: 0.7289393	test1: 0.7131943	best: 0.7132762 (408)	total: 43.1s	remaining: 2m 46s
# 420:	test: 0.7293678	test1: 0.7134751	best: 0.7135523 (417)	total: 44.1s	remaining: 2m 45s
# 430:	test: 0.7296242	test1: 0.7137740	best: 0.7137740 (430)	total: 45s	remaining: 2m 43s
# 440:	test: 0.7300292	test1: 0.7140853	best: 0.7142624 (437)	total: 46s	remaining: 2m 42s
# 450:	test: 0.7302886	test1: 0.7142037	best: 0.7142624 (437)	total: 47s	remaining: 2m 41s
# 460:	test: 0.7307017	test1: 0.7148386	best: 0.7148386 (460)	total: 48.1s	remaining: 2m 40s
# 470:	test: 0.7313438	test1: 0.7148939	best: 0.7149598 (469)	total: 49.1s	remaining: 2m 39s
# 480:	test: 0.7316714	test1: 0.7150407	best: 0.7150407 (480)	total: 50.2s	remaining: 2m 38s
# 490:	test: 0.7321277	test1: 0.7151822	best: 0.7151963 (486)	total: 51.3s	remaining: 2m 37s
# 500:	test: 0.7323026	test1: 0.7154554	best: 0.7154767 (498)	total: 52.3s	remaining: 2m 36s
# 510:	test: 0.7327198	test1: 0.7156837	best: 0.7156989 (509)	total: 53.4s	remaining: 2m 35s
# 520:	test: 0.7331148	test1: 0.7159435	best: 0.7159435 (520)	total: 54.5s	remaining: 2m 34s
# 530:	test: 0.7335790	test1: 0.7159084	best: 0.7160060 (522)	total: 55.7s	remaining: 2m 34s
# 540:	test: 0.7337973	test1: 0.7159678	best: 0.7160060 (522)	total: 56.8s	remaining: 2m 33s
# 550:	test: 0.7339652	test1: 0.7161403	best: 0.7161403 (550)	total: 57.9s	remaining: 2m 32s
# 560:	test: 0.7342932	test1: 0.7165544	best: 0.7165731 (558)	total: 58.9s	remaining: 2m 31s
# 570:	test: 0.7345513	test1: 0.7166821	best: 0.7168033 (566)	total: 60s	remaining: 2m 30s
# 580:	test: 0.7348579	test1: 0.7167664	best: 0.7168296 (577)	total: 1m	remaining: 2m 28s
# 590:	test: 0.7351907	test1: 0.7166737	best: 0.7168296 (577)	total: 1m 1s	remaining: 2m 27s
# 600:	test: 0.7354573	test1: 0.7166273	best: 0.7168296 (577)	total: 1m 2s	remaining: 2m 26s
# 610:	test: 0.7356879	test1: 0.7166923	best: 0.7168296 (577)	total: 1m 3s	remaining: 2m 25s
# 620:	test: 0.7360016	test1: 0.7169788	best: 0.7169788 (620)	total: 1m 4s	remaining: 2m 23s
# 630:	test: 0.7362614	test1: 0.7172638	best: 0.7173682 (626)	total: 1m 5s	remaining: 2m 22s
# 640:	test: 0.7363790	test1: 0.7173484	best: 0.7175375 (639)	total: 1m 6s	remaining: 2m 21s
# 650:	test: 0.7367541	test1: 0.7176638	best: 0.7176638 (650)	total: 1m 7s	remaining: 2m 20s
# 660:	test: 0.7370262	test1: 0.7178235	best: 0.7178235 (660)	total: 1m 8s	remaining: 2m 18s
# 670:	test: 0.7372821	test1: 0.7178343	best: 0.7179065 (666)	total: 1m 9s	remaining: 2m 17s
# 680:	test: 0.7375410	test1: 0.7180168	best: 0.7180168 (680)	total: 1m 10s	remaining: 2m 17s
# 690:	test: 0.7377867	test1: 0.7178950	best: 0.7180168 (680)	total: 1m 11s	remaining: 2m 16s
# 700:	test: 0.7382681	test1: 0.7179139	best: 0.7181061 (692)	total: 1m 13s	remaining: 2m 15s
# 710:	test: 0.7383872	test1: 0.7180487	best: 0.7181061 (692)	total: 1m 13s	remaining: 2m 14s
# 720:	test: 0.7387267	test1: 0.7180668	best: 0.7181061 (692)	total: 1m 14s	remaining: 2m 12s
# 730:	test: 0.7390250	test1: 0.7181741	best: 0.7182132 (728)	total: 1m 15s	remaining: 2m 11s
# 740:	test: 0.7393084	test1: 0.7182245	best: 0.7182245 (740)	total: 1m 16s	remaining: 2m 10s
# 750:	test: 0.7396056	test1: 0.7183187	best: 0.7183200 (749)	total: 1m 17s	remaining: 2m 9s
# 760:	test: 0.7398106	test1: 0.7184114	best: 0.7184187 (759)	total: 1m 18s	remaining: 2m 8s
# 770:	test: 0.7400868	test1: 0.7184145	best: 0.7184908 (768)	total: 1m 19s	remaining: 2m 7s
# 780:	test: 0.7403771	test1: 0.7186798	best: 0.7186798 (780)	total: 1m 20s	remaining: 2m 6s
# 790:	test: 0.7405085	test1: 0.7186247	best: 0.7186798 (780)	total: 1m 21s	remaining: 2m 5s
# 800:	test: 0.7406570	test1: 0.7188065	best: 0.7188065 (800)	total: 1m 22s	remaining: 2m 4s
# 810:	test: 0.7409398	test1: 0.7187982	best: 0.7188173 (808)	total: 1m 23s	remaining: 2m 3s
# 820:	test: 0.7411389	test1: 0.7188692	best: 0.7188923 (816)	total: 1m 24s	remaining: 2m 2s
# 830:	test: 0.7412103	test1: 0.7187604	best: 0.7188927 (828)	total: 1m 25s	remaining: 2m
# 840:	test: 0.7413427	test1: 0.7190104	best: 0.7190104 (840)	total: 1m 26s	remaining: 1m 59s
# 850:	test: 0.7415926	test1: 0.7189758	best: 0.7190104 (840)	total: 1m 27s	remaining: 1m 58s
# 860:	test: 0.7418980	test1: 0.7193099	best: 0.7193192 (857)	total: 1m 28s	remaining: 1m 57s
# 870:	test: 0.7419371	test1: 0.7194397	best: 0.7194583 (868)	total: 1m 29s	remaining: 1m 56s
# 880:	test: 0.7420939	test1: 0.7195005	best: 0.7195737 (874)	total: 1m 30s	remaining: 1m 55s
# 890:	test: 0.7424069	test1: 0.7194225	best: 0.7195737 (874)	total: 1m 31s	remaining: 1m 54s
# 900:	test: 0.7425597	test1: 0.7195986	best: 0.7195986 (900)	total: 1m 32s	remaining: 1m 53s
# 910:	test: 0.7427487	test1: 0.7198238	best: 0.7198238 (910)	total: 1m 33s	remaining: 1m 52s
# 920:	test: 0.7431134	test1: 0.7198842	best: 0.7200036 (917)	total: 1m 34s	remaining: 1m 51s
# 930:	test: 0.7432018	test1: 0.7200127	best: 0.7200127 (930)	total: 1m 35s	remaining: 1m 50s
# 940:	test: 0.7435705	test1: 0.7199882	best: 0.7200631 (934)	total: 1m 36s	remaining: 1m 49s
# 950:	test: 0.7436955	test1: 0.7201647	best: 0.7201716 (949)	total: 1m 37s	remaining: 1m 47s
# 960:	test: 0.7440479	test1: 0.7200598	best: 0.7201716 (949)	total: 1m 38s	remaining: 1m 46s
# 970:	test: 0.7441174	test1: 0.7201158	best: 0.7201716 (949)	total: 1m 39s	remaining: 1m 45s
# 980:	test: 0.7442351	test1: 0.7201732	best: 0.7202780 (978)	total: 1m 40s	remaining: 1m 44s
# 990:	test: 0.7443714	test1: 0.7202290	best: 0.7202780 (978)	total: 1m 41s	remaining: 1m 43s
# 1000:	test: 0.7446108	test1: 0.7202334	best: 0.7203413 (993)	total: 1m 42s	remaining: 1m 42s
# 1010:	test: 0.7449463	test1: 0.7202366	best: 0.7203413 (993)	total: 1m 43s	remaining: 1m 41s
# 1020:	test: 0.7450313	test1: 0.7202386	best: 0.7203802 (1018)	total: 1m 44s	remaining: 1m 40s
# 1030:	test: 0.7451084	test1: 0.7201846	best: 0.7203835 (1026)	total: 1m 45s	remaining: 1m 39s
# 1040:	test: 0.7453075	test1: 0.7202619	best: 0.7203835 (1026)	total: 1m 46s	remaining: 1m 38s
# 1050:	test: 0.7454887	test1: 0.7204104	best: 0.7205286 (1048)	total: 1m 47s	remaining: 1m 37s
# 1060:	test: 0.7456734	test1: 0.7203883	best: 0.7205286 (1048)	total: 1m 48s	remaining: 1m 36s
# 1070:	test: 0.7458104	test1: 0.7204701	best: 0.7205286 (1048)	total: 1m 49s	remaining: 1m 35s
# 1080:	test: 0.7460606	test1: 0.7203768	best: 0.7205286 (1048)	total: 1m 50s	remaining: 1m 34s
# 1090:	test: 0.7461501	test1: 0.7202829	best: 0.7205286 (1048)	total: 1m 51s	remaining: 1m 32s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7205286273
# bestIteration = 1048
#
# Shrink model to first 1049 iterations.
# Fold 4, Valid score = 0.72053
# 0:	test: 0.6583143	test1: 0.6608317	best: 0.6608317 (0)	total: 107ms	remaining: 3m 34s
# 10:	test: 0.7008754	test1: 0.6995269	best: 0.6995269 (10)	total: 1.11s	remaining: 3m 21s
# 20:	test: 0.7017771	test1: 0.7003585	best: 0.7014955 (15)	total: 2.12s	remaining: 3m 20s
# 30:	test: 0.7033839	test1: 0.7011089	best: 0.7014955 (15)	total: 3.13s	remaining: 3m 18s
# 40:	test: 0.7034752	test1: 0.7019423	best: 0.7019423 (40)	total: 4.14s	remaining: 3m 17s
# 50:	test: 0.7047638	test1: 0.7031516	best: 0.7033575 (46)	total: 5.12s	remaining: 3m 15s
# 60:	test: 0.7063683	test1: 0.7041470	best: 0.7045925 (58)	total: 6.13s	remaining: 3m 14s
# 70:	test: 0.7078227	test1: 0.7056292	best: 0.7056292 (70)	total: 7.14s	remaining: 3m 14s
# 80:	test: 0.7082676	test1: 0.7055434	best: 0.7056292 (70)	total: 8.18s	remaining: 3m 13s
# 90:	test: 0.7087010	test1: 0.7058315	best: 0.7058954 (89)	total: 9.17s	remaining: 3m 12s
# 100:	test: 0.7089999	test1: 0.7054974	best: 0.7058954 (89)	total: 10.1s	remaining: 3m 10s
# 110:	test: 0.7093479	test1: 0.7058194	best: 0.7058954 (89)	total: 11.2s	remaining: 3m 10s
# 120:	test: 0.7094080	test1: 0.7056998	best: 0.7063102 (114)	total: 12.2s	remaining: 3m 9s
# 130:	test: 0.7093928	test1: 0.7059596	best: 0.7063102 (114)	total: 13.2s	remaining: 3m 8s
# 140:	test: 0.7097527	test1: 0.7062908	best: 0.7064076 (138)	total: 14.3s	remaining: 3m 7s
# 150:	test: 0.7101357	test1: 0.7063862	best: 0.7064248 (141)	total: 15.3s	remaining: 3m 6s
# 160:	test: 0.7105071	test1: 0.7068486	best: 0.7068486 (160)	total: 16.3s	remaining: 3m 5s
# 170:	test: 0.7115174	test1: 0.7072192	best: 0.7073023 (169)	total: 17.3s	remaining: 3m 4s
# 180:	test: 0.7128921	test1: 0.7086219	best: 0.7086219 (180)	total: 18.3s	remaining: 3m 3s
# 190:	test: 0.7136894	test1: 0.7088191	best: 0.7089033 (184)	total: 19.2s	remaining: 3m 2s
# 200:	test: 0.7144310	test1: 0.7098446	best: 0.7098446 (200)	total: 20.2s	remaining: 3m 1s
# 210:	test: 0.7153464	test1: 0.7101110	best: 0.7102812 (207)	total: 21.2s	remaining: 2m 59s
# 220:	test: 0.7161784	test1: 0.7108759	best: 0.7108759 (220)	total: 22.2s	remaining: 2m 58s
# 230:	test: 0.7168345	test1: 0.7115055	best: 0.7115691 (228)	total: 23.2s	remaining: 2m 57s
# 240:	test: 0.7170143	test1: 0.7118086	best: 0.7119064 (238)	total: 24.1s	remaining: 2m 55s
# 250:	test: 0.7176399	test1: 0.7124977	best: 0.7125685 (249)	total: 25.1s	remaining: 2m 54s
# 260:	test: 0.7183010	test1: 0.7129429	best: 0.7132614 (259)	total: 26s	remaining: 2m 53s
# 270:	test: 0.7189481	test1: 0.7138766	best: 0.7138766 (270)	total: 27s	remaining: 2m 52s
# 280:	test: 0.7195504	test1: 0.7139242	best: 0.7139556 (273)	total: 28s	remaining: 2m 51s
# 290:	test: 0.7199453	test1: 0.7142179	best: 0.7143188 (285)	total: 29s	remaining: 2m 50s
# 300:	test: 0.7204577	test1: 0.7146509	best: 0.7146509 (300)	total: 30.1s	remaining: 2m 49s
# 310:	test: 0.7208671	test1: 0.7145050	best: 0.7147227 (303)	total: 31s	remaining: 2m 48s
# 320:	test: 0.7215930	test1: 0.7151633	best: 0.7151633 (320)	total: 32.1s	remaining: 2m 47s
# 330:	test: 0.7222806	test1: 0.7160214	best: 0.7160214 (330)	total: 33s	remaining: 2m 46s
# 340:	test: 0.7227886	test1: 0.7165791	best: 0.7166407 (338)	total: 34s	remaining: 2m 45s
# 350:	test: 0.7235081	test1: 0.7169390	best: 0.7170477 (347)	total: 35s	remaining: 2m 44s
# 360:	test: 0.7239635	test1: 0.7171806	best: 0.7171806 (360)	total: 36s	remaining: 2m 43s
# 370:	test: 0.7245937	test1: 0.7176631	best: 0.7176631 (370)	total: 37s	remaining: 2m 42s
# 380:	test: 0.7250697	test1: 0.7178687	best: 0.7179314 (373)	total: 38s	remaining: 2m 41s
# 390:	test: 0.7256424	test1: 0.7180621	best: 0.7180621 (390)	total: 39.1s	remaining: 2m 40s
# 400:	test: 0.7259540	test1: 0.7181818	best: 0.7182685 (396)	total: 40.1s	remaining: 2m 39s
# 410:	test: 0.7265205	test1: 0.7183972	best: 0.7184951 (408)	total: 41.1s	remaining: 2m 38s
# 420:	test: 0.7270529	test1: 0.7186971	best: 0.7187968 (418)	total: 42.1s	remaining: 2m 37s
# 430:	test: 0.7275451	test1: 0.7191721	best: 0.7192205 (429)	total: 43.1s	remaining: 2m 36s
# 440:	test: 0.7280926	test1: 0.7194822	best: 0.7194962 (439)	total: 44.1s	remaining: 2m 35s
# 450:	test: 0.7284925	test1: 0.7197542	best: 0.7197594 (449)	total: 45.1s	remaining: 2m 34s
# 460:	test: 0.7289429	test1: 0.7202466	best: 0.7202466 (460)	total: 46.1s	remaining: 2m 33s
# 470:	test: 0.7293394	test1: 0.7204387	best: 0.7204387 (470)	total: 47s	remaining: 2m 32s
# 480:	test: 0.7296515	test1: 0.7206833	best: 0.7206833 (480)	total: 48.1s	remaining: 2m 31s
# 490:	test: 0.7299736	test1: 0.7206875	best: 0.7208761 (485)	total: 49.1s	remaining: 2m 30s
# 500:	test: 0.7303867	test1: 0.7209809	best: 0.7209809 (500)	total: 50.1s	remaining: 2m 29s
# 510:	test: 0.7307436	test1: 0.7210795	best: 0.7211211 (503)	total: 51s	remaining: 2m 28s
# 520:	test: 0.7310227	test1: 0.7211547	best: 0.7211842 (511)	total: 52s	remaining: 2m 27s
# 530:	test: 0.7314646	test1: 0.7215586	best: 0.7215586 (530)	total: 53s	remaining: 2m 26s
# 540:	test: 0.7318403	test1: 0.7215976	best: 0.7216821 (539)	total: 54.1s	remaining: 2m 25s
# 550:	test: 0.7321550	test1: 0.7215788	best: 0.7216821 (539)	total: 55.1s	remaining: 2m 24s
# 560:	test: 0.7326401	test1: 0.7217498	best: 0.7218649 (554)	total: 56.1s	remaining: 2m 23s
# 570:	test: 0.7330154	test1: 0.7216707	best: 0.7219330 (564)	total: 57.1s	remaining: 2m 22s
# 580:	test: 0.7333272	test1: 0.7217709	best: 0.7219330 (564)	total: 58s	remaining: 2m 21s
# 590:	test: 0.7335533	test1: 0.7219499	best: 0.7219951 (588)	total: 59.1s	remaining: 2m 20s
# 600:	test: 0.7338391	test1: 0.7220934	best: 0.7220934 (600)	total: 1m	remaining: 2m 19s
# 610:	test: 0.7342140	test1: 0.7220259	best: 0.7221079 (608)	total: 1m 1s	remaining: 2m 18s
# 620:	test: 0.7343296	test1: 0.7221284	best: 0.7221669 (612)	total: 1m 2s	remaining: 2m 17s
# 630:	test: 0.7346018	test1: 0.7224598	best: 0.7224598 (630)	total: 1m 3s	remaining: 2m 16s
# 640:	test: 0.7350244	test1: 0.7223050	best: 0.7224598 (630)	total: 1m 4s	remaining: 2m 15s
# 650:	test: 0.7352335	test1: 0.7224321	best: 0.7224711 (645)	total: 1m 4s	remaining: 2m 14s
# 660:	test: 0.7355468	test1: 0.7226814	best: 0.7226814 (660)	total: 1m 5s	remaining: 2m 13s
# 670:	test: 0.7358919	test1: 0.7229500	best: 0.7229500 (670)	total: 1m 6s	remaining: 2m 12s
# 680:	test: 0.7361769	test1: 0.7231600	best: 0.7231600 (680)	total: 1m 7s	remaining: 2m 11s
# 690:	test: 0.7365632	test1: 0.7231771	best: 0.7233661 (687)	total: 1m 8s	remaining: 2m 10s
# 700:	test: 0.7367907	test1: 0.7235339	best: 0.7235339 (700)	total: 1m 9s	remaining: 2m 9s
# 710:	test: 0.7370909	test1: 0.7236543	best: 0.7236550 (709)	total: 1m 10s	remaining: 2m 8s
# 720:	test: 0.7373614	test1: 0.7236936	best: 0.7237238 (715)	total: 1m 11s	remaining: 2m 7s
# 730:	test: 0.7375626	test1: 0.7239316	best: 0.7239432 (729)	total: 1m 12s	remaining: 2m 6s
# 740:	test: 0.7377891	test1: 0.7241867	best: 0.7242118 (739)	total: 1m 13s	remaining: 2m 5s
# 750:	test: 0.7380222	test1: 0.7241201	best: 0.7243002 (742)	total: 1m 14s	remaining: 2m 4s
# 760:	test: 0.7382272	test1: 0.7242769	best: 0.7243002 (742)	total: 1m 15s	remaining: 2m 3s
# 770:	test: 0.7385541	test1: 0.7245926	best: 0.7245926 (770)	total: 1m 16s	remaining: 2m 2s
# 780:	test: 0.7388865	test1: 0.7244511	best: 0.7245926 (770)	total: 1m 17s	remaining: 2m 1s
# 790:	test: 0.7391762	test1: 0.7245447	best: 0.7245926 (770)	total: 1m 18s	remaining: 2m
# 800:	test: 0.7394589	test1: 0.7245659	best: 0.7246343 (791)	total: 1m 19s	remaining: 1m 59s
# 810:	test: 0.7397353	test1: 0.7245585	best: 0.7246343 (791)	total: 1m 20s	remaining: 1m 58s
# 820:	test: 0.7399488	test1: 0.7246681	best: 0.7247389 (817)	total: 1m 21s	remaining: 1m 57s
# 830:	test: 0.7402586	test1: 0.7248297	best: 0.7248297 (830)	total: 1m 22s	remaining: 1m 56s
# 840:	test: 0.7403591	test1: 0.7247592	best: 0.7248297 (830)	total: 1m 23s	remaining: 1m 55s
# 850:	test: 0.7405282	test1: 0.7246789	best: 0.7248297 (830)	total: 1m 24s	remaining: 1m 54s
# 860:	test: 0.7407074	test1: 0.7248225	best: 0.7248297 (830)	total: 1m 25s	remaining: 1m 53s
# 870:	test: 0.7409808	test1: 0.7248437	best: 0.7249032 (864)	total: 1m 26s	remaining: 1m 52s
# 880:	test: 0.7412529	test1: 0.7248559	best: 0.7249032 (864)	total: 1m 27s	remaining: 1m 51s
# 890:	test: 0.7414688	test1: 0.7249631	best: 0.7249631 (890)	total: 1m 28s	remaining: 1m 50s
# 900:	test: 0.7416158	test1: 0.7247999	best: 0.7249815 (891)	total: 1m 29s	remaining: 1m 49s
# 910:	test: 0.7417741	test1: 0.7249990	best: 0.7249990 (910)	total: 1m 30s	remaining: 1m 48s
# 920:	test: 0.7420210	test1: 0.7249996	best: 0.7250644 (911)	total: 1m 31s	remaining: 1m 47s
# 930:	test: 0.7422401	test1: 0.7251754	best: 0.7251822 (922)	total: 1m 32s	remaining: 1m 46s
# 940:	test: 0.7423835	test1: 0.7253115	best: 0.7253334 (937)	total: 1m 33s	remaining: 1m 45s
# 950:	test: 0.7426925	test1: 0.7251692	best: 0.7253334 (937)	total: 1m 34s	remaining: 1m 44s
# 960:	test: 0.7428693	test1: 0.7252076	best: 0.7253334 (937)	total: 1m 35s	remaining: 1m 43s
# 970:	test: 0.7430438	test1: 0.7252459	best: 0.7253334 (937)	total: 1m 36s	remaining: 1m 42s
# 980:	test: 0.7432736	test1: 0.7253721	best: 0.7253730 (979)	total: 1m 37s	remaining: 1m 41s
# 990:	test: 0.7435260	test1: 0.7253228	best: 0.7253820 (984)	total: 1m 38s	remaining: 1m 40s
# 1000:	test: 0.7437164	test1: 0.7253060	best: 0.7253820 (984)	total: 1m 39s	remaining: 1m 39s
# 1010:	test: 0.7439723	test1: 0.7254240	best: 0.7255095 (1009)	total: 1m 40s	remaining: 1m 38s
# 1020:	test: 0.7441888	test1: 0.7254752	best: 0.7255118 (1018)	total: 1m 41s	remaining: 1m 37s
# 1030:	test: 0.7442646	test1: 0.7254743	best: 0.7255118 (1018)	total: 1m 42s	remaining: 1m 36s
# 1040:	test: 0.7444910	test1: 0.7255075	best: 0.7255118 (1018)	total: 1m 43s	remaining: 1m 35s
# 1050:	test: 0.7446494	test1: 0.7255153	best: 0.7255277 (1047)	total: 1m 44s	remaining: 1m 34s
# 1060:	test: 0.7449247	test1: 0.7255336	best: 0.7255470 (1059)	total: 1m 45s	remaining: 1m 33s
# 1070:	test: 0.7452019	test1: 0.7256299	best: 0.7256543 (1066)	total: 1m 46s	remaining: 1m 32s
# 1080:	test: 0.7454106	test1: 0.7257180	best: 0.7257234 (1079)	total: 1m 47s	remaining: 1m 31s
# 1090:	test: 0.7456981	test1: 0.7256081	best: 0.7257608 (1084)	total: 1m 48s	remaining: 1m 30s
# 1100:	test: 0.7458562	test1: 0.7256987	best: 0.7257608 (1084)	total: 1m 49s	remaining: 1m 29s
# 1110:	test: 0.7460096	test1: 0.7258169	best: 0.7259336 (1105)	total: 1m 50s	remaining: 1m 28s
# 1120:	test: 0.7461784	test1: 0.7258271	best: 0.7259336 (1105)	total: 1m 51s	remaining: 1m 27s
# 1130:	test: 0.7463243	test1: 0.7258174	best: 0.7259336 (1105)	total: 1m 52s	remaining: 1m 26s
# 1140:	test: 0.7466169	test1: 0.7258342	best: 0.7259336 (1105)	total: 1m 53s	remaining: 1m 25s
# 1150:	test: 0.7467131	test1: 0.7259309	best: 0.7259568 (1143)	total: 1m 53s	remaining: 1m 24s
# 1160:	test: 0.7469886	test1: 0.7259997	best: 0.7260171 (1159)	total: 1m 54s	remaining: 1m 23s
# 1170:	test: 0.7471439	test1: 0.7260387	best: 0.7260387 (1170)	total: 1m 55s	remaining: 1m 22s
# 1180:	test: 0.7474236	test1: 0.7260449	best: 0.7260449 (1180)	total: 1m 56s	remaining: 1m 21s
# 1190:	test: 0.7476488	test1: 0.7259618	best: 0.7260924 (1186)	total: 1m 57s	remaining: 1m 20s
# 1200:	test: 0.7478729	test1: 0.7260342	best: 0.7260924 (1186)	total: 1m 58s	remaining: 1m 19s
# 1210:	test: 0.7480984	test1: 0.7258910	best: 0.7260924 (1186)	total: 1m 59s	remaining: 1m 18s
# 1220:	test: 0.7482507	test1: 0.7259387	best: 0.7260924 (1186)	total: 2m	remaining: 1m 17s
# 1230:	test: 0.7483964	test1: 0.7261336	best: 0.7261336 (1230)	total: 2m 1s	remaining: 1m 16s
# 1240:	test: 0.7486040	test1: 0.7260977	best: 0.7261336 (1230)	total: 2m 2s	remaining: 1m 15s
# 1250:	test: 0.7489073	test1: 0.7261102	best: 0.7261715 (1247)	total: 2m 3s	remaining: 1m 14s
# 1260:	test: 0.7491566	test1: 0.7263840	best: 0.7263840 (1260)	total: 2m 4s	remaining: 1m 13s
# 1270:	test: 0.7493531	test1: 0.7264561	best: 0.7264561 (1270)	total: 2m 5s	remaining: 1m 12s
# 1280:	test: 0.7494923	test1: 0.7263825	best: 0.7265007 (1273)	total: 2m 6s	remaining: 1m 11s
# 1290:	test: 0.7496968	test1: 0.7265554	best: 0.7265671 (1288)	total: 2m 7s	remaining: 1m 10s
# 1300:	test: 0.7498481	test1: 0.7263856	best: 0.7265671 (1288)	total: 2m 8s	remaining: 1m 8s
# 1310:	test: 0.7500377	test1: 0.7261342	best: 0.7265671 (1288)	total: 2m 9s	remaining: 1m 8s
# 1320:	test: 0.7503168	test1: 0.7261560	best: 0.7265671 (1288)	total: 2m 10s	remaining: 1m 6s
# 1330:	test: 0.7504124	test1: 0.7261404	best: 0.7265671 (1288)	total: 2m 11s	remaining: 1m 5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7265671424
# bestIteration = 1288
#
# Shrink model to first 1289 iterations.
# Fold 5, Valid score = 0.72657
# Score by each fold: [0.72194, 0.72659, 0.73284, 0.72053, 0.72657]
# =================================================================

# %%
oof_score = roc_auc_score(
    target, oof_preds
)
print(f"OOF-score = {round(oof_score, 5)}")
# [0.72194, 0.72659, 0.73283, 0.72053, 0.72657]
# OOF-score = 0.72481
# Out:
# OOF-score = 0.72481

# %% [markdown]
# ## Подготовка прогноза

# %%
y_pred = np.zeros(test.shape[0])
test[numerical] = test[numerical].astype(float)
test[categorial] = test[categorial].astype(str)

for estimator in estimators:
    y_pred += estimator.predict_proba(test)[:, 1]

# %%
 = pd.DataFrame({
    "APPLICATION_NUMBER": test_id,
    "TARGET": y_pred / cv.n_splits
})
y_pred.to_csv("./geekbrains-competitive-data-analysis/baseline_submit.csv", index=False)
# Out:
#         APPLICATION_NUMBER    TARGET
# 110093           123724268  0.056370
# 110094           123456549  0.222611
# 110095           123428178  0.185588
# 110096           123619984  0.084373
# 110097           123671104  0.020926
# ...                    ...       ...
# 275229           123487967  0.084373
# 275230           123536402  0.046302
# 275231           123718238  0.084373
# 275232           123631557  0.019437
# 275233           123433260  0.048823
#
# [165141 rows x 2 columns]
